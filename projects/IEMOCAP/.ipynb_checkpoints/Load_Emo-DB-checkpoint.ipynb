# %% [markdown]
# # Emo-DBをロードする
#
# - Emo-DBをロードするプログラム
# - 要求: 2個上の階層にdownload(Emo-DBが管理されてるディレクトリ)
# - return: Emo-DBのwavとラベル(話者や感情の情報込み)のセット

# %%
import numpy as np
import librosa
import librosa.display
import audeer
import wave
import os
import matplotlib.pyplot as plt
import audformat
import soundfile as sf
import audiofile as af
# %matplotlib inline

# %% [markdown]
# ## 前準備

# %%
#音声ファイルをロードするメソッド
def load_wave_data(audio_dir, file_name):
    file_path = os.path.join(audio_dir, file_name)
    x, fs = librosa.load(file_path, sr=16000)
    return x, fs

# %%
#ファイル名から特定の情報を返すメソッド
def parse_names(names, from_i, to_i, is_number=False, mapping=None):
    for name in names:
        key = name[from_i:to_i]
        if is_number:
            key = int(key)
        yield mapping[key] if mapping else key

# %%
# wavがあるディレクトリへのpath
Emo_DB_dir = '../../download/wav/'

# %%
# wavファイル1つ1つへのpath
files = sorted([os.path.join(Emo_DB_dir, f) for f in os.listdir(Emo_DB_dir)])

# %%
# 拡張子と絶対パスを除いたファイル名
names = [audeer.basename_wo_ext(f) for f in files]

# %%
male = audformat.define.Gender.MALE
female = audformat.define.Gender.FEMALE
language = audformat.utils.map_language('de')

# %%
# ファイル名と話者の間のディクショナリ
speaker_mapping = {
    3: {'gender': male, 'age': 31, 'language': language},
    8: {'gender': female, 'age': 34, 'language': language},
    9: {'gender': female, 'age': 21, 'language': language},
    10: {'gender': male, 'age': 32, 'language': language},
    11: {'gender': male, 'age': 26, 'language': language},
    12: {'gender': male, 'age': 30, 'language': language},
    13: {'gender': female, 'age': 32, 'language': language},
    14: {'gender': female, 'age': 35, 'language': language},
    15: {'gender': male, 'age': 25, 'language': language},
    16: {'gender': female, 'age': 31, 'language': language},
}

# %%
# ファイル名と感情ラベルの間のディクショナリ
emotion_mapping = {
    'W': 'Anger',
    'L': 'Boredom',
    'E': 'Disgust',
    'A': 'Fear',
    'F': 'Happiness',
    'T': 'Sadness',
    'N': 'Neutral',
}

# %%
# ファイルごとの話者
speakers = list(parse_names(names, from_i=0, to_i=2, is_number=True))

# %%
# ファイルごとの感情ラベル
emotions = list(parse_names(names, from_i=5, to_i=6, mapping=emotion_mapping))

# %%
emotions
# Out:
# ['Happiness',
#  'Neutral',
#  'Anger',
#  'Happiness',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Neutral',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Disgust',
#  'Disgust',
#  'Boredom',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Disgust',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Disgust',
#  'Neutral',
#  'Anger',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Disgust',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Anger',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Anger',
#  'Boredom',
#  'Sadness',
#  'Fear',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Disgust',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Boredom',
#  'Sadness',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Fear',
#  'Happiness',
#  'Neutral',
#  'Anger',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Boredom',
#  'Neutral',
#  'Neutral',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Disgust',
#  'Disgust',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Boredom',
#  'Sadness',
#  'Anger',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Happiness',
#  'Boredom',
#  'Neutral',
#  'Sadness',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Boredom',
#  'Anger',
#  'Fear',
#  'Disgust',
#  'Happiness',
#  'Boredom',
#  'Sadness',
#  'Sadness',
#  'Anger',
#  'Anger']

# %%
files
# Out:
# ['../../download/wav/03a01Fa.wav',
#  '../../download/wav/03a01Nc.wav',
#  '../../download/wav/03a01Wa.wav',
#  '../../download/wav/03a02Fc.wav',
#  '../../download/wav/03a02Nc.wav',
#  '../../download/wav/03a02Ta.wav',
#  '../../download/wav/03a02Wb.wav',
#  '../../download/wav/03a02Wc.wav',
#  '../../download/wav/03a04Ad.wav',
#  '../../download/wav/03a04Fd.wav',
#  '../../download/wav/03a04Lc.wav',
#  '../../download/wav/03a04Nc.wav',
#  '../../download/wav/03a04Ta.wav',
#  '../../download/wav/03a04Wc.wav',
#  '../../download/wav/03a05Aa.wav',
#  '../../download/wav/03a05Fc.wav',
#  '../../download/wav/03a05Nd.wav',
#  '../../download/wav/03a05Tc.wav',
#  '../../download/wav/03a05Wa.wav',
#  '../../download/wav/03a05Wb.wav',
#  '../../download/wav/03a07Fa.wav',
#  '../../download/wav/03a07Fb.wav',
#  '../../download/wav/03a07La.wav',
#  '../../download/wav/03a07Nc.wav',
#  '../../download/wav/03a07Wc.wav',
#  '../../download/wav/03b01Fa.wav',
#  '../../download/wav/03b01Lb.wav',
#  '../../download/wav/03b01Nb.wav',
#  '../../download/wav/03b01Td.wav',
#  '../../download/wav/03b01Wa.wav',
#  '../../download/wav/03b01Wc.wav',
#  '../../download/wav/03b02Aa.wav',
#  '../../download/wav/03b02La.wav',
#  '../../download/wav/03b02Na.wav',
#  '../../download/wav/03b02Tb.wav',
#  '../../download/wav/03b02Wb.wav',
#  '../../download/wav/03b03Nb.wav',
#  '../../download/wav/03b03Tc.wav',
#  '../../download/wav/03b03Wc.wav',
#  '../../download/wav/03b09La.wav',
#  '../../download/wav/03b09Nc.wav',
#  '../../download/wav/03b09Tc.wav',
#  '../../download/wav/03b09Wa.wav',
#  '../../download/wav/03b10Ab.wav',
#  '../../download/wav/03b10Ec.wav',
#  '../../download/wav/03b10Na.wav',
#  '../../download/wav/03b10Nc.wav',
#  '../../download/wav/03b10Wb.wav',
#  '../../download/wav/03b10Wc.wav',
#  '../../download/wav/08a01Ab.wav',
#  '../../download/wav/08a01Fd.wav',
#  '../../download/wav/08a01Lc.wav',
#  '../../download/wav/08a01Na.wav',
#  '../../download/wav/08a01Wa.wav',
#  '../../download/wav/08a01Wc.wav',
#  '../../download/wav/08a02Ab.wav',
#  '../../download/wav/08a02Ac.wav',
#  '../../download/wav/08a02Fe.wav',
#  '../../download/wav/08a02La.wav',
#  '../../download/wav/08a02Na.wav',
#  '../../download/wav/08a02Tb.wav',
#  '../../download/wav/08a02Wc.wav',
#  '../../download/wav/08a04Ff.wav',
#  '../../download/wav/08a04La.wav',
#  '../../download/wav/08a04Nc.wav',
#  '../../download/wav/08a04Tb.wav',
#  '../../download/wav/08a04Wc.wav',
#  '../../download/wav/08a05Fe.wav',
#  '../../download/wav/08a05Lc.wav',
#  '../../download/wav/08a05Nb.wav',
#  '../../download/wav/08a05Ta.wav',
#  '../../download/wav/08a05Wa.wav',
#  '../../download/wav/08a07Fd.wav',
#  '../../download/wav/08a07La.wav',
#  '../../download/wav/08a07Na.wav',
#  '../../download/wav/08a07Ta.wav',
#  '../../download/wav/08a07Tb.wav',
#  '../../download/wav/08a07Wc.wav',
#  '../../download/wav/08b01Aa.wav',
#  '../../download/wav/08b01Fd.wav',
#  '../../download/wav/08b01Fe.wav',
#  '../../download/wav/08b01Lb.wav',
#  '../../download/wav/08b01Na.wav',
#  '../../download/wav/08b01Wa.wav',
#  '../../download/wav/08b02Ff.wav',
#  '../../download/wav/08b02La.wav',
#  '../../download/wav/08b02Nb.wav',
#  '../../download/wav/08b02Tc.wav',
#  '../../download/wav/08b02Wd.wav',
#  '../../download/wav/08b03Fe.wav',
#  '../../download/wav/08b03Lc.wav',
#  '../../download/wav/08b03Nb.wav',
#  '../../download/wav/08b03Tc.wav',
#  '../../download/wav/08b03Wd.wav',
#  '../../download/wav/08b09Ab.wav',
#  '../../download/wav/08b09Fd.wav',
#  '../../download/wav/08b09Lc.wav',
#  '../../download/wav/08b09Nb.wav',
#  '../../download/wav/08b09Tb.wav',
#  '../../download/wav/08b09Wa.wav',
#  '../../download/wav/08b09Wc.wav',
#  '../../download/wav/08b10Aa.wav',
#  '../../download/wav/08b10Fd.wav',
#  '../../download/wav/08b10La.wav',
#  '../../download/wav/08b10Nc.wav',
#  '../../download/wav/08b10Tc.wav',
#  '../../download/wav/08b10Wa.wav',
#  '../../download/wav/09a01Ea.wav',
#  '../../download/wav/09a01Fa.wav',
#  '../../download/wav/09a01Nb.wav',
#  '../../download/wav/09a01Wb.wav',
#  '../../download/wav/09a02Ea.wav',
#  '../../download/wav/09a02Eb.wav',
#  '../../download/wav/09a02La.wav',
#  '../../download/wav/09a02Wb.wav',
#  '../../download/wav/09a04Fd.wav',
#  '../../download/wav/09a04La.wav',
#  '../../download/wav/09a04Nb.wav',
#  '../../download/wav/09a04Wa.wav',
#  '../../download/wav/09a05Ed.wav',
#  '../../download/wav/09a05Lc.wav',
#  '../../download/wav/09a05Nb.wav',
#  '../../download/wav/09a05Tb.wav',
#  '../../download/wav/09a05Wb.wav',
#  '../../download/wav/09a05Wc.wav',
#  '../../download/wav/09a07Eb.wav',
#  '../../download/wav/09a07Na.wav',
#  '../../download/wav/09a07Ta.wav',
#  '../../download/wav/09a07Wb.wav',
#  '../../download/wav/09a07Wd.wav',
#  '../../download/wav/09b01Ea.wav',
#  '../../download/wav/09b01Na.wav',
#  '../../download/wav/09b01Wb.wav',
#  '../../download/wav/09b02Na.wav',
#  '../../download/wav/09b02Tb.wav',
#  '../../download/wav/09b02Wc.wav',
#  '../../download/wav/09b02Wd.wav',
#  '../../download/wav/09b03Ed.wav',
#  '../../download/wav/09b03Fa.wav',
#  '../../download/wav/09b03Fd.wav',
#  '../../download/wav/09b03Lb.wav',
#  '../../download/wav/09b03Nb.wav',
#  '../../download/wav/09b03Ta.wav',
#  '../../download/wav/09b03Wb.wav',
#  '../../download/wav/09b09Ea.wav',
#  '../../download/wav/09b09Nd.wav',
#  '../../download/wav/09b09Wa.wav',
#  '../../download/wav/09b10Aa.wav',
#  '../../download/wav/09b10Nd.wav',
#  '../../download/wav/09b10Wa.wav',
#  '../../download/wav/10a01Ac.wav',
#  '../../download/wav/10a01Nb.wav',
#  '../../download/wav/10a01Wa.wav',
#  '../../download/wav/10a02Ab.wav',
#  '../../download/wav/10a02Fa.wav',
#  '../../download/wav/10a02Lb.wav',
#  '../../download/wav/10a02Na.wav',
#  '../../download/wav/10a02Wa.wav',
#  '../../download/wav/10a04Fd.wav',
#  '../../download/wav/10a04Nb.wav',
#  '../../download/wav/10a04Wa.wav',
#  '../../download/wav/10a04Wb.wav',
#  '../../download/wav/10a05Aa.wav',
#  '../../download/wav/10a05Ld.wav',
#  '../../download/wav/10a05Tb.wav',
#  '../../download/wav/10a05Wb.wav',
#  '../../download/wav/10a07Aa.wav',
#  '../../download/wav/10a07Ad.wav',
#  '../../download/wav/10a07La.wav',
#  '../../download/wav/10a07Ta.wav',
#  '../../download/wav/10a07Wb.wav',
#  '../../download/wav/10b01Aa.wav',
#  '../../download/wav/10b01Ea.wav',
#  '../../download/wav/10b01Fa.wav',
#  '../../download/wav/10b01Lb.wav',
#  '../../download/wav/10b02Aa.wav',
#  '../../download/wav/10b02La.wav',
#  '../../download/wav/10b02Na.wav',
#  '../../download/wav/10b02Wb.wav',
#  '../../download/wav/10b03La.wav',
#  '../../download/wav/10b03Tb.wav',
#  '../../download/wav/10b03Wb.wav',
#  '../../download/wav/10b09Ad.wav',
#  '../../download/wav/10b09Lb.wav',
#  '../../download/wav/10b09Wb.wav',
#  '../../download/wav/10b10Fc.wav',
#  '../../download/wav/10b10Lc.wav',
#  '../../download/wav/10b10Wa.wav',
#  '../../download/wav/11a01Aa.wav',
#  '../../download/wav/11a01Ab.wav',
#  '../../download/wav/11a01Ld.wav',
#  '../../download/wav/11a01Nd.wav',
#  '../../download/wav/11a01Wc.wav',
#  '../../download/wav/11a02Ec.wav',
#  '../../download/wav/11a02Fb.wav',
#  '../../download/wav/11a02Ld.wav',
#  '../../download/wav/11a02Nc.wav',
#  '../../download/wav/11a02Tc.wav',
#  '../../download/wav/11a02Wc.wav',
#  '../../download/wav/11a04Ac.wav',
#  '../../download/wav/11a04Fd.wav',
#  '../../download/wav/11a04Nd.wav',
#  '../../download/wav/11a04Wc.wav',
#  '../../download/wav/11a05Ad.wav',
#  '../../download/wav/11a05Fb.wav',
#  '../../download/wav/11a05Fc.wav',
#  '../../download/wav/11a05Lc.wav',
#  '../../download/wav/11a05Na.wav',
#  '../../download/wav/11a05Td.wav',
#  '../../download/wav/11a05Wd.wav',
#  '../../download/wav/11a07Ac.wav',
#  '../../download/wav/11a07Ld.wav',
#  '../../download/wav/11a07Ta.wav',
#  '../../download/wav/11a07Wc.wav',
#  '../../download/wav/11b01Ab.wav',
#  '../../download/wav/11b01Eb.wav',
#  '../../download/wav/11b01Fc.wav',
#  '../../download/wav/11b01Lb.wav',
#  '../../download/wav/11b01Nc.wav',
#  '../../download/wav/11b01Wd.wav',
#  '../../download/wav/11b02Ab.wav',
#  '../../download/wav/11b02Fd.wav',
#  '../../download/wav/11b02Na.wav',
#  '../../download/wav/11b02Td.wav',
#  '../../download/wav/11b02Wb.wav',
#  '../../download/wav/11b03Fc.wav',
#  '../../download/wav/11b03Lc.wav',
#  '../../download/wav/11b03Nb.wav',
#  '../../download/wav/11b03Td.wav',
#  '../../download/wav/11b03Wa.wav',
#  '../../download/wav/11b03Wb.wav',
#  '../../download/wav/11b09Ad.wav',
#  '../../download/wav/11b09Fd.wav',
#  '../../download/wav/11b09Ld.wav',
#  '../../download/wav/11b09Na.wav',
#  '../../download/wav/11b09Td.wav',
#  '../../download/wav/11b09Wa.wav',
#  '../../download/wav/11b10Ad.wav',
#  '../../download/wav/11b10Ae.wav',
#  '../../download/wav/11b10Ld.wav',
#  '../../download/wav/11b10Nc.wav',
#  '../../download/wav/11b10Td.wav',
#  '../../download/wav/11b10Wa.wav',
#  '../../download/wav/12a01Fb.wav',
#  '../../download/wav/12a01Lb.wav',
#  '../../download/wav/12a01Nb.wav',
#  '../../download/wav/12a01Wc.wav',
#  '../../download/wav/12a02Ac.wav',
#  '../../download/wav/12a02Ec.wav',
#  '../../download/wav/12a02Nb.wav',
#  '../../download/wav/12a02Wa.wav',
#  '../../download/wav/12a02Wc.wav',
#  '../../download/wav/12a04Wc.wav',
#  '../../download/wav/12a05Ab.wav',
#  '../../download/wav/12a05Lb.wav',
#  '../../download/wav/12a05Nd.wav',
#  '../../download/wav/12a05Ta.wav',
#  '../../download/wav/12a05Wb.wav',
#  '../../download/wav/12a07Ac.wav',
#  '../../download/wav/12a07La.wav',
#  '../../download/wav/12a07Wa.wav',
#  '../../download/wav/12b01Ta.wav',
#  '../../download/wav/12b01Wa.wav',
#  '../../download/wav/12b02Ad.wav',
#  '../../download/wav/12b02Ea.wav',
#  '../../download/wav/12b02Fb.wav',
#  '../../download/wav/12b02Na.wav',
#  '../../download/wav/12b02Wa.wav',
#  '../../download/wav/12b02Wb.wav',
#  '../../download/wav/12b02Wd.wav',
#  '../../download/wav/12b03La.wav',
#  '../../download/wav/12b03Ta.wav',
#  '../../download/wav/12b09Ac.wav',
#  '../../download/wav/12b09Td.wav',
#  '../../download/wav/12b09Wc.wav',
#  '../../download/wav/12b10Ac.wav',
#  '../../download/wav/12b10Ld.wav',
#  '../../download/wav/12b10Wa.wav',
#  '../../download/wav/13a01Ac.wav',
#  '../../download/wav/13a01Ea.wav',
#  '../../download/wav/13a01Ec.wav',
#  '../../download/wav/13a01Fd.wav',
#  '../../download/wav/13a01Lb.wav',
#  '../../download/wav/13a01Nb.wav',
#  '../../download/wav/13a01Wb.wav',
#  '../../download/wav/13a02Ad.wav',
#  '../../download/wav/13a02Ec.wav',
#  '../../download/wav/13a02Fa.wav',
#  '../../download/wav/13a02Lc.wav',
#  '../../download/wav/13a02Nc.wav',
#  '../../download/wav/13a02Ta.wav',
#  '../../download/wav/13a02Wa.wav',
#  '../../download/wav/13a04Ac.wav',
#  '../../download/wav/13a04Fc.wav',
#  '../../download/wav/13a04Lb.wav',
#  '../../download/wav/13a04Ta.wav',
#  '../../download/wav/13a04Wc.wav',
#  '../../download/wav/13a05Aa.wav',
#  '../../download/wav/13a05Ea.wav',
#  '../../download/wav/13a05Lc.wav',
#  '../../download/wav/13a05Nb.wav',
#  '../../download/wav/13a05Tc.wav',
#  '../../download/wav/13a05Wa.wav',
#  '../../download/wav/13a05Wc.wav',
#  '../../download/wav/13a07Fd.wav',
#  '../../download/wav/13a07Lb.wav',
#  '../../download/wav/13a07Na.wav',
#  '../../download/wav/13a07Tc.wav',
#  '../../download/wav/13a07Wb.wav',
#  '../../download/wav/13b01Ab.wav',
#  '../../download/wav/13b01Ec.wav',
#  '../../download/wav/13b01Fc.wav',
#  '../../download/wav/13b01Ld.wav',
#  '../../download/wav/13b01Nc.wav',
#  '../../download/wav/13b01Wa.wav',
#  '../../download/wav/13b02Fb.wav',
#  '../../download/wav/13b02Lc.wav',
#  '../../download/wav/13b02Nb.wav',
#  '../../download/wav/13b02Wa.wav',
#  '../../download/wav/13b03Ac.wav',
#  '../../download/wav/13b03Ed.wav',
#  '../../download/wav/13b03Fd.wav',
#  '../../download/wav/13b03Lb.wav',
#  '../../download/wav/13b03Na.wav',
#  '../../download/wav/13b03Td.wav',
#  '../../download/wav/13b03Wc.wav',
#  '../../download/wav/13b09Ab.wav',
#  '../../download/wav/13b09Ec.wav',
#  '../../download/wav/13b09Fb.wav',
#  '../../download/wav/13b09Fc.wav',
#  '../../download/wav/13b09La.wav',
#  '../../download/wav/13b09Na.wav',
#  '../../download/wav/13b09Wa.wav',
#  '../../download/wav/13b10Ec.wav',
#  '../../download/wav/13b10Fa.wav',
#  '../../download/wav/13b10La.wav',
#  '../../download/wav/13b10Nc.wav',
#  '../../download/wav/13b10Wa.wav',
#  '../../download/wav/13b10Wc.wav',
#  '../../download/wav/14a01Aa.wav',
#  '../../download/wav/14a01Ac.wav',
#  '../../download/wav/14a01Ea.wav',
#  '../../download/wav/14a01Na.wav',
#  '../../download/wav/14a01Wa.wav',
#  '../../download/wav/14a01Wc.wav',
#  '../../download/wav/14a02Ab.wav',
#  '../../download/wav/14a02Ea.wav',
#  '../../download/wav/14a02Fd.wav',
#  '../../download/wav/14a02La.wav',
#  '../../download/wav/14a02Nc.wav',
#  '../../download/wav/14a02Tb.wav',
#  '../../download/wav/14a02Wa.wav',
#  '../../download/wav/14a02Wc.wav',
#  '../../download/wav/14a04Aa.wav',
#  '../../download/wav/14a04Ed.wav',
#  '../../download/wav/14a04Lb.wav',
#  '../../download/wav/14a04Tb.wav',
#  '../../download/wav/14a04Tc.wav',
#  '../../download/wav/14a04Wb.wav',
#  '../../download/wav/14a04Wc.wav',
#  '../../download/wav/14a05Aa.wav',
#  '../../download/wav/14a05Ac.wav',
#  '../../download/wav/14a05Fa.wav',
#  '../../download/wav/14a05Fb.wav',
#  '../../download/wav/14a05Lb.wav',
#  '../../download/wav/14a05Na.wav',
#  '../../download/wav/14a05Ta.wav',
#  '../../download/wav/14a05Tc.wav',
#  '../../download/wav/14a05Wa.wav',
#  '../../download/wav/14a05Wb.wav',
#  '../../download/wav/14a07Aa.wav',
#  '../../download/wav/14a07Eb.wav',
#  '../../download/wav/14a07Fd.wav',
#  '../../download/wav/14a07Lc.wav',
#  '../../download/wav/14a07Ld.wav',
#  '../../download/wav/14a07Na.wav',
#  '../../download/wav/14a07Tc.wav',
#  '../../download/wav/14a07Wc.wav',
#  '../../download/wav/14b01Ac.wav',
#  '../../download/wav/14b01Eb.wav',
#  '../../download/wav/14b01Fa.wav',
#  '../../download/wav/14b01Fc.wav',
#  '../../download/wav/14b01Na.wav',
#  '../../download/wav/14b01Wc.wav',
#  '../../download/wav/14b02Aa.wav',
#  '../../download/wav/14b02Fb.wav',
#  '../../download/wav/14b02Na.wav',
#  '../../download/wav/14b02Tc.wav',
#  '../../download/wav/14b02Wb.wav',
#  '../../download/wav/14b02Wd.wav',
#  '../../download/wav/14b03Ad.wav',
#  '../../download/wav/14b03Ed.wav',
#  '../../download/wav/14b03Lb.wav',
#  '../../download/wav/14b03Ta.wav',
#  '../../download/wav/14b03Wb.wav',
#  '../../download/wav/14b09Ac.wav',
#  '../../download/wav/14b09Ea.wav',
#  '../../download/wav/14b09Fc.wav',
#  '../../download/wav/14b09Lb.wav',
#  '../../download/wav/14b09Td.wav',
#  '../../download/wav/14b09Wa.wav',
#  '../../download/wav/14b09Wc.wav',
#  '../../download/wav/14b10Ad.wav',
#  '../../download/wav/14b10Eb.wav',
#  '../../download/wav/14b10Lb.wav',
#  '../../download/wav/14b10Nb.wav',
#  '../../download/wav/14b10Tc.wav',
#  '../../download/wav/14b10Wc.wav',
#  '../../download/wav/15a01Ea.wav',
#  '../../download/wav/15a01Fb.wav',
#  '../../download/wav/15a01La.wav',
#  '../../download/wav/15a01Nb.wav',
#  '../../download/wav/15a01Wa.wav',
#  '../../download/wav/15a02Ac.wav',
#  '../../download/wav/15a02Ea.wav',
#  '../../download/wav/15a02La.wav',
#  '../../download/wav/15a02Na.wav',
#  '../../download/wav/15a02Ta.wav',
#  '../../download/wav/15a02Wb.wav',
#  '../../download/wav/15a02Wd.wav',
#  '../../download/wav/15a04Ab.wav',
#  '../../download/wav/15a04Ac.wav',
#  '../../download/wav/15a04Fd.wav',
#  '../../download/wav/15a04Nc.wav',
#  '../../download/wav/15a04Wa.wav',
#  '../../download/wav/15a04Wb.wav',
#  '../../download/wav/15a05Eb.wav',
#  '../../download/wav/15a05Fb.wav',
#  '../../download/wav/15a05Lb.wav',
#  '../../download/wav/15a05Na.wav',
#  '../../download/wav/15a05Wa.wav',
#  '../../download/wav/15a07Ac.wav',
#  '../../download/wav/15a07Eb.wav',
#  '../../download/wav/15a07Fa.wav',
#  '../../download/wav/15a07Fb.wav',
#  '../../download/wav/15a07Ld.wav',
#  '../../download/wav/15a07Nc.wav',
#  '../../download/wav/15b01Ec.wav',
#  '../../download/wav/15b01Lb.wav',
#  '../../download/wav/15b01Na.wav',
#  '../../download/wav/15b01Wc.wav',
#  '../../download/wav/15b02Aa.wav',
#  '../../download/wav/15b02Lb.wav',
#  '../../download/wav/15b02Nd.wav',
#  '../../download/wav/15b02Tc.wav',
#  '../../download/wav/15b02Wa.wav',
#  '../../download/wav/15b02Wc.wav',
#  '../../download/wav/15b03Aa.wav',
#  '../../download/wav/15b03Lc.wav',
#  '../../download/wav/15b03Nb.wav',
#  '../../download/wav/15b03Tc.wav',
#  '../../download/wav/15b03Wa.wav',
#  '../../download/wav/15b03Wb.wav',
#  '../../download/wav/15b09Ac.wav',
#  '../../download/wav/15b09Fa.wav',
#  '../../download/wav/15b09La.wav',
#  '../../download/wav/15b09Nb.wav',
#  '../../download/wav/15b09Ta.wav',
#  '../../download/wav/15b09Wb.wav',
#  '../../download/wav/15b10Ac.wav',
#  '../../download/wav/15b10Lc.wav',
#  '../../download/wav/15b10Nb.wav',
#  '../../download/wav/15b10Nc.wav',
#  '../../download/wav/15b10Wa.wav',
#  '../../download/wav/16a01Ec.wav',
#  '../../download/wav/16a01Fc.wav',
#  '../../download/wav/16a01Lb.wav',
#  '../../download/wav/16a01Nc.wav',
#  '../../download/wav/16a01Tb.wav',
#  '../../download/wav/16a01Wb.wav',
#  '../../download/wav/16a02Ea.wav',
#  '../../download/wav/16a02Ec.wav',
#  '../../download/wav/16a02Lb.wav',
#  '../../download/wav/16a02Nb.wav',
#  '../../download/wav/16a02Tc.wav',
#  '../../download/wav/16a02Wb.wav',
#  '../../download/wav/16a04Ab.wav',
#  '../../download/wav/16a04Ea.wav',
#  '../../download/wav/16a04Fa.wav',
#  '../../download/wav/16a04La.wav',
#  '../../download/wav/16a04Lc.wav',
#  '../../download/wav/16a04Nc.wav',
#  '../../download/wav/16a04Tc.wav',
#  '../../download/wav/16a04Wb.wav',
#  '../../download/wav/16a04Wc.wav',
#  '../../download/wav/16a05Ab.wav',
#  '../../download/wav/16a05Ea.wav',
#  '../../download/wav/16a05Fc.wav',
#  '../../download/wav/16a05La.wav',
#  '../../download/wav/16a05Tb.wav',
#  '../../download/wav/16a05Wb.wav',
#  '../../download/wav/16a05Wc.wav',
#  '../../download/wav/16a07Ea.wav',
#  '../../download/wav/16a07Fa.wav',
#  '../../download/wav/16a07Fb.wav',
#  '../../download/wav/16a07La.wav',
#  '../../download/wav/16a07Lb.wav',
#  '../../download/wav/16a07Nb.wav',
#  '../../download/wav/16a07Td.wav',
#  '../../download/wav/16a07Wa.wav',
#  '../../download/wav/16b01Aa.wav',
#  '../../download/wav/16b01Eb.wav',
#  '../../download/wav/16b01Fa.wav',
#  '../../download/wav/16b01La.wav',
#  '../../download/wav/16b01Lc.wav',
#  '../../download/wav/16b01Tb.wav',
#  '../../download/wav/16b01Wa.wav',
#  '../../download/wav/16b01Wb.wav',
#  '../../download/wav/16b02Aa.wav',
#  '../../download/wav/16b02Eb.wav',
#  '../../download/wav/16b02Fd.wav',
#  '../../download/wav/16b02Lb.wav',
#  '../../download/wav/16b02Wb.wav',
#  '../../download/wav/16b03Ad.wav',
#  '../../download/wav/16b03Ea.wav',
#  '../../download/wav/16b03Fa.wav',
#  '../../download/wav/16b03Fd.wav',
#  '../../download/wav/16b03La.wav',
#  '../../download/wav/16b03Nb.wav',
#  '../../download/wav/16b03Ta.wav',
#  '../../download/wav/16b03Wb.wav',
#  '../../download/wav/16b09Ab.wav',
#  '../../download/wav/16b09Eb.wav',
#  '../../download/wav/16b09Fb.wav',
#  '../../download/wav/16b09La.wav',
#  '../../download/wav/16b09Lb.wav',
#  '../../download/wav/16b09Wb.wav',
#  '../../download/wav/16b10Aa.wav',
#  '../../download/wav/16b10Eb.wav',
#  '../../download/wav/16b10Fb.wav',
#  '../../download/wav/16b10Lb.wav',
#  '../../download/wav/16b10Tb.wav',
#  '../../download/wav/16b10Td.wav',
#  '../../download/wav/16b10Wa.wav',
#  '../../download/wav/16b10Wb.wav']

# %%
dataset = []
for file, speaker, emotion in zip(files, speakers, emotions):
    x, fs = librosa.load(file, sr=16000)
    dataset.append([x, emotion, speaker])

# %%
dataset
# Out:
# [[array([ 0.00067139,  0.00308228,  0.00253296, ..., -0.00231934,
#          -0.00186157, -0.00186157], dtype=float32),
#   'Happiness',
#   3],
#  [array([ 2.7465820e-04,  9.1552734e-05,  3.9672852e-04, ...,
#          -9.1552734e-05, -2.1362305e-04, -3.0517578e-05], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.0000000e+00,  3.0517578e-05, -1.5258789e-04, ...,
#          -3.9672852e-04, -4.5776367e-04, -1.5258789e-04], dtype=float32),
#   'Anger',
#   3],
#  [array([0.0007019 , 0.00250244, 0.00268555, ..., 0.00024414, 0.00015259,
#          0.        ], dtype=float32),
#   'Happiness',
#   3],
#  [array([ 6.1035156e-05, -3.0517578e-04, -1.5258789e-04, ...,
#           2.1362305e-04,  6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Neutral',
#   3],
#  [array([0.        , 0.        , 0.00021362, ..., 0.00021362, 0.00021362,
#          0.        ], dtype=float32),
#   'Sadness',
#   3],
#  [array([0.00265503, 0.00320435, 0.00411987, ..., 0.00076294, 0.00076294,
#          0.00076294], dtype=float32),
#   'Anger',
#   3],
#  [array([ 9.1552734e-05,  1.2207031e-04,  6.1035156e-05, ...,
#          -4.5776367e-04, -3.9672852e-04, -3.9672852e-04], dtype=float32),
#   'Anger',
#   3],
#  [array([ 1.5258789e-04, -1.5869141e-03, -9.1552734e-04, ...,
#           6.1035156e-05,  0.0000000e+00, -6.1035156e-05], dtype=float32),
#   'Fear',
#   3],
#  [array([ 3.0517578e-05, -9.1552734e-05, -2.7465820e-04, ...,
#           3.0517578e-05,  1.2207031e-04,  0.0000000e+00], dtype=float32),
#   'Happiness',
#   3],
#  [array([ 0.00140381,  0.00140381,  0.00161743, ..., -0.00213623,
#          -0.00198364, -0.00183105], dtype=float32),
#   'Boredom',
#   3],
#  [array([ 0.        ,  0.        ,  0.        , ..., -0.00067139,
#          -0.00030518, -0.00064087], dtype=float32),
#   'Neutral',
#   3],
#  [array([0.00039673, 0.00039673, 0.00039673, ..., 0.        , 0.00039673,
#          0.        ], dtype=float32),
#   'Sadness',
#   3],
#  [array([ 0.0000000e+00,  5.1879883e-04,  8.2397461e-04, ...,
#           3.0517578e-05,  0.0000000e+00, -6.1035156e-05], dtype=float32),
#   'Anger',
#   3],
#  [array([ 0.        ,  0.00024414,  0.00024414, ..., -0.00186157,
#          -0.00128174, -0.00015259], dtype=float32),
#   'Fear',
#   3],
#  [array([0.00244141, 0.00204468, 0.00280762, ..., 0.00231934, 0.00216675,
#          0.00204468], dtype=float32),
#   'Happiness',
#   3],
#  [array([-3.5095215e-03, -3.4179688e-03, -3.5095215e-03, ...,
#          -1.8310547e-04, -2.7465820e-04, -6.1035156e-05], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.00021362, -0.0007019 ,  0.        , ..., -0.00115967,
#          -0.00091553, -0.0007019 ], dtype=float32),
#   'Sadness',
#   3],
#  [array([ 0.0000000e+00, -3.0517578e-05,  3.0517578e-05, ...,
#          -7.3242188e-04, -9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   3],
#  [array([ 0.00027466, -0.00018311, -0.00030518, ..., -0.00036621,
#          -0.00027466, -0.00033569], dtype=float32),
#   'Anger',
#   3],
#  [array([-5.4931641e-04, -1.1901855e-03, -2.2888184e-03, ...,
#          -3.0517578e-04, -7.6293945e-04, -9.1552734e-05], dtype=float32),
#   'Happiness',
#   3],
#  [array([ 2.5634766e-03,  2.6245117e-03,  2.5634766e-03, ...,
#           9.1552734e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   3],
#  [array([-0.00775146, -0.00756836, -0.00775146, ...,  0.00158691,
#           0.00140381,  0.00015259], dtype=float32),
#   'Boredom',
#   3],
#  [array([ 0.00018311,  0.00045776,  0.00027466, ..., -0.00018311,
#          -0.00018311, -0.00018311], dtype=float32),
#   'Neutral',
#   3],
#  [array([6.1035156e-05, 7.0190430e-04, 7.3242188e-04, ..., 5.1879883e-04,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   3],
#  [array([ 0.0020752 ,  0.00305176,  0.0027771 , ..., -0.0027771 ,
#          -0.00292969, -0.00439453], dtype=float32),
#   'Happiness',
#   3],
#  [array([-0.0020752 , -0.00119019, -0.00180054, ..., -0.00088501,
#          -0.0020752 , -0.00180054], dtype=float32),
#   'Boredom',
#   3],
#  [array([ 0.00033569,  0.00021362,  0.00027466, ..., -0.00033569,
#          -0.00033569, -0.00033569], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.00076294,  0.00094604,  0.00112915, ..., -0.00054932,
#           0.00018311, -0.00018311], dtype=float32),
#   'Sadness',
#   3],
#  [array([3.0517578e-05, 3.0517578e-05, 3.0517578e-05, ..., 2.3193359e-03,
#          2.3498535e-03, 2.3193359e-03], dtype=float32),
#   'Anger',
#   3],
#  [array([-0.00097656, -0.00106812, -0.00085449, ..., -0.00024414,
#          -0.00018311, -0.00018311], dtype=float32),
#   'Anger',
#   3],
#  [array([ 0.        , -0.00036621,  0.00015259, ..., -0.0032959 ,
#          -0.00250244, -0.00180054], dtype=float32),
#   'Fear',
#   3],
#  [array([-0.00335693, -0.003479  , -0.00335693, ...,  0.00057983,
#           0.00042725,  0.        ], dtype=float32),
#   'Boredom',
#   3],
#  [array([ 6.1035156e-05,  0.0000000e+00, -2.1362305e-04, ...,
#           1.1291504e-03,  7.9345703e-04,  1.2207031e-04], dtype=float32),
#   'Neutral',
#   3],
#  [array([-0.00320435, -0.00320435, -0.00369263, ...,  0.00030518,
#          -0.00015259, -0.00030518], dtype=float32),
#   'Sadness',
#   3],
#  [array([ 0.00125122,  0.00112915,  0.00076294, ..., -0.00054932,
#          -0.00030518, -0.00015259], dtype=float32),
#   'Anger',
#   3],
#  [array([ 3.3569336e-04,  2.4414062e-04,  3.9672852e-04, ...,
#           3.0517578e-05,  9.1552734e-05, -3.0517578e-05], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.00561523,  0.00561523,  0.00598145, ...,  0.00012207,
#          -0.00024414,  0.        ], dtype=float32),
#   'Sadness',
#   3],
#  [array([ 3.0517578e-05, -3.0517578e-05,  3.0517578e-05, ...,
#           3.0517578e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   3],
#  [array([-6.4086914e-03, -6.0424805e-03, -6.1035156e-03, ...,
#          -6.1035156e-05, -3.0517578e-04, -1.5258789e-04], dtype=float32),
#   'Boredom',
#   3],
#  [array([3.3569336e-04, 1.5258789e-04, 3.0517578e-04, ..., 9.1552734e-05,
#          1.5258789e-04, 0.0000000e+00], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.00021362,  0.        ,  0.        , ...,  0.00042725,
#           0.        , -0.00021362], dtype=float32),
#   'Sadness',
#   3],
#  [array([ 0.0000000e+00, -6.1035156e-05, -1.2207031e-04, ...,
#          -2.4414062e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   3],
#  [array([ 0.0000000e+00, -9.1552734e-05, -1.5258789e-04, ...,
#           0.0000000e+00, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Fear',
#   3],
#  [array([ 1.4343262e-03,  1.6784668e-03, -3.0517578e-05, ...,
#           5.6152344e-03,  8.1176758e-03,  6.5917969e-03], dtype=float32),
#   'Disgust',
#   3],
#  [array([ 0.0000000e+00,  0.0000000e+00, -3.0517578e-05, ...,
#          -2.0446777e-03, -1.9836426e-03, -1.9836426e-03], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 0.0010376 ,  0.00637817,  0.00616455, ..., -0.00030518,
#          -0.00033569, -0.00024414], dtype=float32),
#   'Neutral',
#   3],
#  [array([ 3.0517578e-05, -3.0517578e-05, -1.2207031e-04, ...,
#          -2.1362305e-04, -1.2207031e-04, -3.9672852e-04], dtype=float32),
#   'Anger',
#   3],
#  [array([ 1.2207031e-04, -3.9672852e-04, -2.7465820e-04, ...,
#           1.5258789e-04, -9.1552734e-05, -1.2207031e-04], dtype=float32),
#   'Anger',
#   3],
#  [array([-3.2653809e-03, -3.4484863e-03, -3.5400391e-03, ...,
#          -9.1552734e-05, -9.1552734e-05, -3.0517578e-05], dtype=float32),
#   'Fear',
#   8],
#  [array([ 0.00048828,  0.00048828,  0.00048828, ..., -0.0012207 ,
#          -0.00048828, -0.00024414], dtype=float32),
#   'Happiness',
#   8],
#  [array([-1.2512207e-03, -1.3427734e-03, -9.7656250e-04, ...,
#          -1.5258789e-04, -1.5258789e-04, -6.1035156e-05], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.0000000e+00, -2.4414062e-04, -3.9672852e-04, ...,
#           7.3242188e-04,  3.9672852e-04,  6.1035156e-05], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.0000000e+00,  0.0000000e+00, -3.0517578e-05, ...,
#           6.1035156e-05,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([ 6.1035156e-05,  3.0517578e-05, -9.1552734e-05, ...,
#           9.1552734e-05,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.0000000e+00, -9.1552734e-05,  0.0000000e+00, ...,
#          -3.6621094e-04, -2.7465820e-04, -1.5258789e-04], dtype=float32),
#   'Fear',
#   8],
#  [array([ 0.        , -0.00021362, -0.00021362, ..., -0.00033569,
#          -0.00021362, -0.00021362], dtype=float32),
#   'Fear',
#   8],
#  [array([ 0.00033569,  0.        , -0.00067139, ...,  0.00042725,
#           0.        ,  0.        ], dtype=float32),
#   'Happiness',
#   8],
#  [array([-1.8310547e-04, -9.1552734e-05,  1.8310547e-04, ...,
#          -3.9367676e-03, -5.1574707e-03, -3.5095215e-03], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.        , -0.00036621, -0.00091553, ...,  0.00064087,
#           0.0005188 , -0.00036621], dtype=float32),
#   'Neutral',
#   8],
#  [array([-0.02145386, -0.02145386, -0.02145386, ..., -0.01275635,
#          -0.01101685, -0.00869751], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 1.2207031e-04,  9.1552734e-05,  9.1552734e-05, ...,
#          -3.0517578e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([0.00027466, 0.00057983, 0.00073242, ..., 0.00012207, 0.00027466,
#          0.00021362], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 1.5258789e-04, -6.1035156e-05, -1.5258789e-04, ...,
#           4.7607422e-03,  5.0964355e-03, -3.2043457e-03], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.00317383,  0.0032959 ,  0.00317383, ..., -0.00115967,
#          -0.00094604, -0.00201416], dtype=float32),
#   'Neutral',
#   8],
#  [array([-0.02493286, -0.02093506, -0.02194214, ...,  0.01196289,
#           0.01394653,  0.01443481], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 0.00021362, -0.00018311, -0.00045776, ..., -0.00033569,
#          -0.00027466, -0.00027466], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.0000000e+00, -9.1552734e-05, -2.1362305e-04, ...,
#          -1.0681152e-03, -7.3242188e-04, -4.2724609e-04], dtype=float32),
#   'Happiness',
#   8],
#  [array([-0.00213623, -0.00082397, -0.00073242, ...,  0.00289917,
#           0.00265503,  0.00256348], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.00033569,  0.00067139,  0.00100708, ...,  0.00076294,
#           0.00024414, -0.00033569], dtype=float32),
#   'Neutral',
#   8],
#  [array([0.012146  , 0.01260376, 0.01260376, ..., 0.00338745, 0.00289917,
#          0.00485229], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 0.        ,  0.        ,  0.        , ..., -0.00064087,
#          -0.0015564 , -0.00164795], dtype=float32),
#   'Anger',
#   8],
#  [array([0.0000000e+00, 9.1552734e-05, 2.1362305e-04, ..., 2.1362305e-04,
#          9.1552734e-05, 9.1552734e-05], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 0.00061035,  0.00039673,  0.0010376 , ..., -0.0010376 ,
#          -0.00039673, -0.00039673], dtype=float32),
#   'Boredom',
#   8],
#  [array([-2.7465820e-04, -9.1552734e-05, -8.2397461e-04, ...,
#          -6.4086914e-04, -1.4648438e-03, -1.6479492e-03], dtype=float32),
#   'Neutral',
#   8],
#  [array([0.03051758, 0.03051758, 0.03051758, ..., 0.00286865, 0.00286865,
#          0.00344849], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 0.00048828, -0.00048828,  0.00097656, ...,  0.01651001,
#           0.0085144 ,  0.        ], dtype=float32),
#   'Sadness',
#   8],
#  [array([7.9345703e-04, 6.1035156e-04, 5.7983398e-04, ..., 6.1035156e-05,
#          6.1035156e-05, 3.0517578e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.0000000e+00, -9.1552734e-05,  0.0000000e+00, ...,
#           1.8310547e-04,  2.7465820e-04,  0.0000000e+00], dtype=float32),
#   'Fear',
#   8],
#  [array([0.00115967, 0.00131226, 0.00042725, ..., 0.00100708, 0.00057983,
#          0.00057983], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 0.0000000e+00,  9.1552734e-05,  9.1552734e-05, ...,
#          -6.3781738e-03, -4.0283203e-03, -1.0070801e-03], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 0.00222778,  0.00222778,  0.00189209, ..., -0.00143433,
#          -0.00143433, -0.00015259], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.        ,  0.00027466,  0.00027466, ..., -0.00115967,
#          -0.00115967, -0.00042725], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          -1.2207031e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([ 7.5073242e-03,  3.6315918e-03, -3.1127930e-03, ...,
#          -2.1362305e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 0.00271606,  0.00250244,  0.00241089, ..., -0.01150513,
#          -0.00683594, -0.00332642], dtype=float32),
#   'Boredom',
#   8],
#  [array([-0.00180054, -0.00180054, -0.00189209, ...,  0.00601196,
#           0.00576782,  0.00592041], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.00183105,  0.00228882,  0.00228882, ..., -0.02359009,
#          -0.02404785, -0.02404785], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 0.0000000e+00, -1.2207031e-04, -6.1035156e-05, ...,
#           6.1035156e-05,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([-0.00079346, -0.00094604, -0.00088501, ...,  0.00469971,
#           0.00466919,  0.00460815], dtype=float32),
#   'Happiness',
#   8],
#  [array([ 0.00405884,  0.00375366,  0.00360107, ..., -0.00830078,
#          -0.00906372, -0.00875854], dtype=float32),
#   'Boredom',
#   8],
#  [array([-6.1035156e-05, -6.7138672e-04, -5.7983398e-04, ...,
#          -2.4414062e-04, -2.4414062e-04,  0.0000000e+00], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.00119019,  0.00158691,  0.00280762, ..., -0.00119019,
#          -0.00158691, -0.00158691], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 6.1035156e-05,  9.1552734e-05,  6.1035156e-05, ...,
#          -4.8828125e-04, -3.3569336e-04, -3.3569336e-04], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.00015259,  0.00030518,  0.00015259, ..., -0.00302124,
#          -0.00506592, -0.00302124], dtype=float32),
#   'Fear',
#   8],
#  [array([ 3.0517578e-05,  3.0517578e-05, -9.1552734e-05, ...,
#          -7.0190430e-04, -5.7983398e-04, -5.7983398e-04], dtype=float32),
#   'Happiness',
#   8],
#  [array([-0.00030518, -0.00045776, -0.00079346, ..., -0.00045776,
#          -0.00045776, -0.00045776], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 6.1035156e-05,  6.1035156e-05,  2.1362305e-04, ...,
#          -2.1362305e-04, -2.7465820e-04, -1.2207031e-04], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.00027466,  0.00057983,  0.00027466, ..., -0.01791382,
#          -0.01730347, -0.01852417], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 2.7465820e-04,  2.7465820e-04,  2.7465820e-04, ...,
#           6.1035156e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.0000000e+00, -1.5258789e-04, -4.2724609e-04, ...,
#          -9.1552734e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([ 3.0517578e-04,  8.2397461e-04,  1.3427734e-03, ...,
#          -1.5563965e-03, -9.1552734e-05, -1.8615723e-03], dtype=float32),
#   'Fear',
#   8],
#  [array([0.0032959 , 0.0112915 , 0.00393677, ..., 0.02120972, 0.02139282,
#          0.02145386], dtype=float32),
#   'Happiness',
#   8],
#  [array([-0.00012207, -0.0022583 , -0.00299072, ...,  0.03445435,
#           0.02972412,  0.02471924], dtype=float32),
#   'Boredom',
#   8],
#  [array([ 0.00036621,  0.00057983,  0.00067139, ..., -0.00082397,
#          -0.00057983, -0.0005188 ], dtype=float32),
#   'Neutral',
#   8],
#  [array([ 0.02151489,  0.02270508,  0.02270508, ..., -0.0027771 ,
#          -0.00198364, -0.00198364], dtype=float32),
#   'Sadness',
#   8],
#  [array([ 3.0517578e-05,  3.0517578e-05,  3.0517578e-05, ...,
#          -3.0517578e-05, -3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'Anger',
#   8],
#  [array([ 0.00030518,  0.00030518,  0.00030518, ..., -0.00308228,
#          -0.00247192, -0.0027771 ], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 0.0000000e+00, -3.0517578e-05, -3.0517578e-05, ...,
#          -2.0446777e-03, -3.9062500e-03, -2.1972656e-03], dtype=float32),
#   'Happiness',
#   9],
#  [array([-0.00216675, -0.00198364, -0.00125122, ...,  0.00015259,
#          -0.00033569, -0.0005188 ], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 3.0517578e-05,  9.1552734e-05,  6.1035156e-05, ...,
#          -3.0517578e-05, -6.1035156e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   9],
#  [array([-0.00195312, -0.00222778, -0.00250244, ...,  0.00027466,
#           0.00027466,  0.00054932], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 3.0517578e-05, -3.0517578e-05,  3.0517578e-05, ...,
#           9.1552734e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 0.        , -0.00027466,  0.        , ...,  0.003479  ,
#           0.00320435,  0.00289917], dtype=float32),
#   'Boredom',
#   9],
#  [array([3.0517578e-05, 9.1552734e-05, 1.8310547e-04, ..., 6.1035156e-05,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   9],
#  [array([1.2207031e-04, 3.0517578e-04, 2.4414062e-04, ..., 0.0000000e+00,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   9],
#  [array([-0.01068115, -0.01068115, -0.01037598, ..., -0.00057983,
#          -0.00146484, -0.00027466], dtype=float32),
#   'Boredom',
#   9],
#  [array([-0.00915527, -0.00888062, -0.00863647, ..., -0.02011108,
#          -0.02111816, -0.02087402], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 6.1035156e-05,  3.0517578e-05,  2.4414062e-04, ...,
#          -6.1035156e-04, -6.7138672e-04, -6.1035156e-04], dtype=float32),
#   'Anger',
#   9],
#  [array([0.00238037, 0.00189209, 0.00140381, ..., 0.        , 0.        ,
#          0.        ], dtype=float32),
#   'Disgust',
#   9],
#  [array([-0.04522705, -0.04443359, -0.04403687, ..., -0.00234985,
#          -0.00076294, -0.00036621], dtype=float32),
#   'Boredom',
#   9],
#  [array([0.00335693, 0.00350952, 0.00335693, ..., 0.00030518, 0.00030518,
#          0.        ], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 0.00091553, -0.00091553, -0.00091553, ..., -0.01208496,
#          -0.01303101, -0.01208496], dtype=float32),
#   'Sadness',
#   9],
#  [array([ 0.0000000e+00, -1.2207031e-04,  0.0000000e+00, ...,
#          -2.1362305e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   9],
#  [array([ 3.0517578e-05,  6.1035156e-05,  9.1552734e-05, ...,
#          -2.4414062e-04, -3.0517578e-04, -3.0517578e-04], dtype=float32),
#   'Anger',
#   9],
#  [array([-0.00366211, -0.00390625, -0.00436401, ..., -0.00067139,
#          -0.00021362, -0.00067139], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 0.00100708,  0.00305176,  0.00271606, ..., -0.00439453,
#          -0.00338745, -0.00167847], dtype=float32),
#   'Neutral',
#   9],
#  [array([0.0138855 , 0.01495361, 0.01708984, ..., 0.00427246, 0.00213623,
#          0.        ], dtype=float32),
#   'Sadness',
#   9],
#  [array([-4.2724609e-04, -4.5776367e-04, -4.8828125e-04, ...,
#           6.1035156e-05,  3.0517578e-05,  9.1552734e-05], dtype=float32),
#   'Anger',
#   9],
#  [array([ 0.0000000e+00,  9.1552734e-05, -1.8310547e-04, ...,
#          -1.8310547e-04, -1.8310547e-04, -9.1552734e-05], dtype=float32),
#   'Anger',
#   9],
#  [array([ 9.1552734e-05,  0.0000000e+00, -9.1552734e-05, ...,
#           2.1362305e-04,  9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 0.00259399,  0.00283813,  0.00283813, ..., -0.00439453,
#          -0.00439453, -0.00439453], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 0.0000000e+00, -6.1035156e-05,  1.2207031e-04, ...,
#          -6.1035156e-05,  0.0000000e+00, -1.2207031e-04], dtype=float32),
#   'Anger',
#   9],
#  [array([ 0.        , -0.00057983, -0.00027466, ..., -0.01196289,
#          -0.01049805, -0.01049805], dtype=float32),
#   'Neutral',
#   9],
#  [array([0.        , 0.        , 0.        , ..., 0.00088501, 0.        ,
#          0.        ], dtype=float32),
#   'Sadness',
#   9],
#  [array([ 0.0027771 ,  0.00534058,  0.0038147 , ..., -0.00048828,
#          -0.00024414,  0.        ], dtype=float32),
#   'Anger',
#   9],
#  [array([9.1552734e-05, 2.9296875e-03, 4.5776367e-04, ..., 0.0000000e+00,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   9],
#  [array([-0.0015564 , -0.00180054, -0.0015564 , ...,  0.00076294,
#           0.00076294,  0.        ], dtype=float32),
#   'Disgust',
#   9],
#  [array([ 6.7138672e-04,  6.1035156e-04,  3.9672852e-04, ...,
#          -1.5258789e-04, -1.8310547e-04, -9.1552734e-05], dtype=float32),
#   'Happiness',
#   9],
#  [array([ 0.0000000e+00, -6.1035156e-05,  0.0000000e+00, ...,
#           6.1035156e-05,  6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Happiness',
#   9],
#  [array([0.0005188 , 0.        , 0.0005188 , ..., 0.0045166 , 0.00506592,
#          0.00534058], dtype=float32),
#   'Boredom',
#   9],
#  [array([-0.0010376 , -0.00131226, -0.0010376 , ..., -0.00769043,
#          -0.00344849, -0.00131226], dtype=float32),
#   'Neutral',
#   9],
#  [array([-0.02032471, -0.01663208, -0.01199341, ...,  0.01754761,
#           0.01663208,  0.01663208], dtype=float32),
#   'Sadness',
#   9],
#  [array([ 8.2397461e-04,  9.7656250e-04, -3.9672852e-04, ...,
#           3.0517578e-05,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Anger',
#   9],
#  [array([ 0.00036621, -0.00036621, -0.00036621, ...,  0.        ,
#          -0.00036621, -0.00036621], dtype=float32),
#   'Disgust',
#   9],
#  [array([-0.0078125 , -0.00671387, -0.00671387, ..., -0.00137329,
#          -0.00109863, -0.00195312], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 0.0000000e+00, -4.2724609e-04, -6.4086914e-04, ...,
#          -9.1552734e-05, -9.1552734e-05, -9.1552734e-05], dtype=float32),
#   'Anger',
#   9],
#  [array([ 0.        , -0.00030518, -0.0015564 , ..., -0.00061035,
#          -0.00061035, -0.00030518], dtype=float32),
#   'Fear',
#   9],
#  [array([ 0.00094604,  0.00143433, -0.00119019, ..., -0.00143433,
#          -0.00143433, -0.0007019 ], dtype=float32),
#   'Neutral',
#   9],
#  [array([ 0.0000000e+00, -9.1552734e-05, -1.5258789e-04, ...,
#          -3.0517578e-05,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Anger',
#   9],
#  [array([-0.00012207, -0.00012207, -0.00024414, ..., -0.00061035,
#          -0.00048828, -0.00024414], dtype=float32),
#   'Fear',
#   10],
#  [array([ 0.00338745,  0.00411987,  0.00369263, ..., -0.00140381,
#          -0.00097656, -0.0015564 ], dtype=float32),
#   'Neutral',
#   10],
#  [array([ 7.0190430e-04, -3.0517578e-04, -1.4953613e-03, ...,
#           1.2207031e-04,  1.2207031e-04, -3.0517578e-05], dtype=float32),
#   'Anger',
#   10],
#  [array([-0.00030518, -0.00045776, -0.00030518, ..., -0.00030518,
#           0.        , -0.00015259], dtype=float32),
#   'Fear',
#   10],
#  [array([ 0.        , -0.00012207, -0.00012207, ..., -0.00012207,
#          -0.00018311, -0.00024414], dtype=float32),
#   'Happiness',
#   10],
#  [array([-0.00372314, -0.00354004, -0.00427246, ...,  0.00073242,
#           0.00036621,  0.00018311], dtype=float32),
#   'Boredom',
#   10],
#  [array([-0.00018311, -0.00054932, -0.00158691, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   'Neutral',
#   10],
#  [array([-0.00057983, -0.0005188 , -0.00073242, ..., -0.00131226,
#          -0.00180054, -0.00143433], dtype=float32),
#   'Anger',
#   10],
#  [array([ 0.00631714,  0.01098633,  0.01550293, ..., -0.00119019,
#          -0.00033569, -0.00109863], dtype=float32),
#   'Happiness',
#   10],
#  [array([ 0.00054932, -0.00109863, -0.00100708, ...,  0.00360107,
#           0.003479  ,  0.00372314], dtype=float32),
#   'Neutral',
#   10],
#  [array([ 0.00946045,  0.01074219,  0.00531006, ..., -0.00079346,
#          -0.00106812, -0.0005188 ], dtype=float32),
#   'Anger',
#   10],
#  [array([ 6.1035156e-05, -9.1552734e-05, -1.5258789e-04, ...,
#           1.8310547e-04,  9.1552734e-05,  9.1552734e-05], dtype=float32),
#   'Anger',
#   10],
#  [array([ 6.7138672e-04,  7.3242188e-04,  5.1879883e-04, ...,
#          -1.2207031e-04, -6.1035156e-05, -1.2207031e-04], dtype=float32),
#   'Fear',
#   10],
#  [array([-0.0022583 , -0.01370239, -0.01751709, ..., -0.00067139,
#          -0.00039673, -0.00088501], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 0.00222778,  0.00073242,  0.00048828, ..., -0.00595093,
#          -0.00570679, -0.00671387], dtype=float32),
#   'Sadness',
#   10],
#  [array([ 0.0000000e+00, -2.7465820e-04, -7.3242188e-04, ...,
#          -3.0517578e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   10],
#  [array([ 0.        , -0.0007019 , -0.0005188 , ..., -0.0007019 ,
#          -0.00015259, -0.00033569], dtype=float32),
#   'Fear',
#   10],
#  [array([ 0.0012207 ,  0.00097656,  0.        , ..., -0.00024414,
#           0.        ,  0.        ], dtype=float32),
#   'Fear',
#   10],
#  [array([ 0.00027466,  0.00125122,  0.00112915, ..., -0.00253296,
#          -0.00463867, -0.00662231], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 0.00024414, -0.00024414, -0.00076294, ..., -0.00048828,
#          -0.00048828, -0.00125122], dtype=float32),
#   'Sadness',
#   10],
#  [array([3.0517578e-05, 9.1552734e-05, 9.1552734e-05, ..., 4.5776367e-04,
#          3.0517578e-04, 6.1035156e-05], dtype=float32),
#   'Anger',
#   10],
#  [array([ 3.5095215e-03,  8.3007812e-03,  1.0437012e-02, ...,
#          -1.5258789e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Fear',
#   10],
#  [array([ 2.1362305e-04,  3.9672852e-04, -6.1035156e-05, ...,
#           2.9296875e-03,  2.9296875e-03,  2.7465820e-03], dtype=float32),
#   'Disgust',
#   10],
#  [array([-0.00326538, -0.00283813, -0.00271606, ...,  0.00317383,
#           0.003479  ,  0.00305176], dtype=float32),
#   'Happiness',
#   10],
#  [array([ 0.0017395 ,  0.00274658,  0.00311279, ..., -0.00061035,
#          -0.00061035, -0.00036621], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 0.00015259,  0.0005188 ,  0.00036621, ..., -0.00021362,
#          -0.00476074, -0.00079346], dtype=float32),
#   'Fear',
#   10],
#  [array([0.00039673, 0.00024414, 0.0005188 , ..., 0.00228882, 0.00189209,
#          0.0012207 ], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 0.00042725, -0.00012207, -0.00033569, ..., -0.00296021,
#          -0.01098633, -0.00967407], dtype=float32),
#   'Neutral',
#   10],
#  [array([ 3.0517578e-05, -6.1035156e-05, -6.1035156e-05, ...,
#          -1.9226074e-03, -1.8615723e-03, -1.8005371e-03], dtype=float32),
#   'Anger',
#   10],
#  [array([ 6.1035156e-05,  3.6621094e-04,  7.3242188e-04, ...,
#          -2.7465820e-04, -9.7656250e-04, -2.1972656e-03], dtype=float32),
#   'Boredom',
#   10],
#  [array([-0.01168823, -0.01168823, -0.012146  , ..., -0.00021362,
#          -0.00042725, -0.00109863], dtype=float32),
#   'Sadness',
#   10],
#  [array([ 0.00317383,  0.00292969,  0.00134277, ..., -0.00119019,
#          -0.0010376 , -0.00088501], dtype=float32),
#   'Anger',
#   10],
#  [array([0.01412964, 0.01513672, 0.01193237, ..., 0.00057983, 0.00057983,
#          0.00018311], dtype=float32),
#   'Fear',
#   10],
#  [array([ 0.00061035,  0.00024414,  0.        , ..., -0.00280762,
#          -0.00134277, -0.00036621], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 3.0517578e-05,  3.3569336e-04,  1.2817383e-03, ...,
#          -4.8828125e-04, -3.6621094e-04, -2.4414062e-04], dtype=float32),
#   'Anger',
#   10],
#  [array([ 2.7465820e-04,  9.1552734e-05,  9.1552734e-05, ...,
#          -9.1552734e-05,  9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Happiness',
#   10],
#  [array([-0.00100708, -0.00247192, -0.00115967, ..., -0.00027466,
#          -0.00027466, -0.00042725], dtype=float32),
#   'Boredom',
#   10],
#  [array([ 3.0517578e-05,  9.1552734e-05, -9.1552734e-05, ...,
#           3.0517578e-04,  1.5258789e-04,  3.0517578e-05], dtype=float32),
#   'Anger',
#   10],
#  [array([ 0.        , -0.00112915, -0.00112915, ...,  0.00112915,
#           0.00036621, -0.00036621], dtype=float32),
#   'Fear',
#   11],
#  [array([ 0.00036621, -0.00036621, -0.00036621, ..., -0.00515747,
#          -0.00552368, -0.00479126], dtype=float32),
#   'Fear',
#   11],
#  [array([-0.0045166 , -0.00509644, -0.00640869, ...,  0.0020752 ,
#           0.00149536, -0.00018311], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 4.2724609e-04,  9.4604492e-04, -6.1035156e-05, ...,
#          -6.1035156e-05,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 3.0517578e-05,  0.0000000e+00, -1.5258789e-04, ...,
#          -1.2207031e-04, -3.0517578e-04, -2.7465820e-04], dtype=float32),
#   'Anger',
#   11],
#  [array([ 0.00036621,  0.00149536,  0.00213623, ..., -0.00427246,
#          -0.00466919, -0.0050354 ], dtype=float32),
#   'Disgust',
#   11],
#  [array([6.1035156e-05, 2.7465820e-04, 4.5776367e-04, ..., 1.8310547e-04,
#          0.0000000e+00, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 0.0007019 , -0.0007019 , -0.00140381, ..., -0.00564575,
#          -0.00512695, -0.00280762], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 2.4414062e-04,  1.5258789e-04, -1.5258789e-04, ...,
#           6.1035156e-05, -1.5258789e-04,  0.0000000e+00], dtype=float32),
#   'Neutral',
#   11],
#  [array([-0.00350952, -0.00387573, -0.00271606, ...,  0.00701904,
#           0.00817871,  0.00817871], dtype=float32),
#   'Sadness',
#   11],
#  [array([9.1552734e-05, 1.8310547e-04, 1.2207031e-04, ..., 9.1552734e-05,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   11],
#  [array([ 0.00012207,  0.        , -0.00012207, ...,  0.00057983,
#           0.00042725, -0.00012207], dtype=float32),
#   'Fear',
#   11],
#  [array([ 0.0000000e+00,  0.0000000e+00, -6.1035156e-05, ...,
#          -1.5258789e-04, -1.8310547e-04, -1.8310547e-04], dtype=float32),
#   'Happiness',
#   11],
#  [array([-0.00250244, -0.00161743, -0.00057983, ..., -0.00027466,
#          -0.00027466, -0.00042725], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 1.5258789e-04,  9.1552734e-05, -9.1552734e-05, ...,
#           1.2207031e-04,  3.0517578e-04,  0.0000000e+00], dtype=float32),
#   'Anger',
#   11],
#  [array([-0.00067139, -0.00067139, -0.0010376 , ..., -0.00085449,
#          -0.00085449, -0.00015259], dtype=float32),
#   'Fear',
#   11],
#  [array([ 1.2207031e-04,  1.2207031e-04, -6.1035156e-05, ...,
#          -6.1035156e-04, -5.4931641e-04, -7.3242188e-04], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 1.2817383e-03,  7.9345703e-04,  3.6621094e-04, ...,
#          -9.1552734e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 0.        , -0.00045776, -0.00021362, ..., -0.00021362,
#          -0.00067139, -0.00045776], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.00082397,  0.00143433,  0.00061035, ..., -0.00100708,
#          -0.00039673, -0.00039673], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 0.00061035,  0.00079346,  0.00079346, ..., -0.00753784,
#          -0.00775146, -0.00775146], dtype=float32),
#   'Sadness',
#   11],
#  [array([ 3.3569336e-04, -3.0517578e-05, -3.0517578e-05, ...,
#           3.0517578e-05,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   11],
#  [array([ 9.1552734e-05, -4.2724609e-04, -4.2724609e-04, ...,
#           2.1362305e-04,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Fear',
#   11],
#  [array([ 3.1439209e-01,  2.9736328e-01,  2.8884888e-01, ...,
#           6.1035156e-04,  1.2207031e-04, -2.4414062e-04], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.        ,  0.00030518, -0.00064087, ..., -0.00097656,
#          -0.00064087, -0.00195312], dtype=float32),
#   'Sadness',
#   11],
#  [array([ 1.5258789e-04,  1.5258789e-04,  3.0517578e-05, ...,
#          -6.1035156e-05, -1.2207031e-04, -6.1035156e-05], dtype=float32),
#   'Anger',
#   11],
#  [array([ 1.1627197e-02,  5.3710938e-03, -3.9672852e-04, ...,
#          -2.7465820e-04, -1.2207031e-04, -6.1035156e-05], dtype=float32),
#   'Fear',
#   11],
#  [array([-0.0012207 , -0.00061035, -0.00091553, ...,  0.00091553,
#           0.00061035,  0.        ], dtype=float32),
#   'Disgust',
#   11],
#  [array([ 3.0517578e-04, -3.0517578e-05, -4.8828125e-04, ...,
#           1.5258789e-04,  1.5258789e-04, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 0.00018311,  0.00073242,  0.00018311, ...,  0.00241089,
#           0.00091553, -0.00018311], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.0012207 ,  0.00247192,  0.00247192, ..., -0.00979614,
#          -0.01010132, -0.01010132], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 2.1362305e-04,  1.8310547e-04, -3.3569336e-04, ...,
#           6.1035156e-05,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Anger',
#   11],
#  [array([-0.00576782, -0.00576782, -0.00570679, ...,  0.00018311,
#           0.00012207,  0.        ], dtype=float32),
#   'Fear',
#   11],
#  [array([2.4108887e-03, 2.6550293e-03, 2.7160645e-03, ..., 4.5776367e-04,
#          9.1552734e-05, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 1.7395020e-03,  1.8310547e-03,  1.8920898e-03, ...,
#           6.1035156e-05, -1.2207031e-04, -1.8310547e-04], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 0.        , -0.00027466, -0.00088501, ..., -0.00210571,
#          -0.00119019, -0.00241089], dtype=float32),
#   'Sadness',
#   11],
#  [array([ 0.00085449,  0.00045776, -0.00064087, ...,  0.00183105,
#           0.00170898,  0.00164795], dtype=float32),
#   'Anger',
#   11],
#  [array([ 3.3569336e-04,  3.9672852e-04,  3.0517578e-04, ...,
#          -3.0517578e-05, -1.5258789e-04, -9.1552734e-05], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 0.        ,  0.        ,  0.00012207, ..., -0.00112915,
#          -0.00125122, -0.00183105], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.        ,  0.00015259,  0.00015259, ..., -0.00079346,
#          -0.00073242, -0.00054932], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 0.00057983, -0.00027466, -0.00027466, ...,  0.        ,
#          -0.00027466, -0.00088501], dtype=float32),
#   'Sadness',
#   11],
#  [array([-0.00094604, -0.0010376 , -0.00119019, ..., -0.00045776,
#          -0.00039673, -0.0005188 ], dtype=float32),
#   'Anger',
#   11],
#  [array([ 3.0517578e-05,  0.0000000e+00, -3.0517578e-05, ...,
#           0.0000000e+00,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   11],
#  [array([ 0.00015259, -0.00015259, -0.00033569, ..., -0.00152588,
#          -0.00152588, -0.00152588], dtype=float32),
#   'Fear',
#   11],
#  [array([ 0.0000000e+00, -4.5776367e-04, -1.5563965e-03, ...,
#          -3.9672852e-04, -1.2207031e-04, -6.1035156e-05], dtype=float32),
#   'Happiness',
#   11],
#  [array([ 0.00128174,  0.0015564 ,  0.0005188 , ...,  0.0005188 ,
#          -0.00024414, -0.00024414], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.        ,  0.0007019 , -0.00012207, ..., -0.00592041,
#          -0.00479126, -0.00436401], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 0.        , -0.0005188 ,  0.00024414, ...,  0.0010376 ,
#           0.0010376 ,  0.        ], dtype=float32),
#   'Sadness',
#   11],
#  [array([ 3.3569336e-04,  6.4086914e-04,  1.8310547e-04, ...,
#           0.0000000e+00, -2.4414062e-04, -9.1552734e-05], dtype=float32),
#   'Anger',
#   11],
#  [array([ 0.00131226,  0.00085449,  0.00042725, ..., -0.00131226,
#          -0.00131226, -0.00042725], dtype=float32),
#   'Fear',
#   11],
#  [array([-0.00363159, -0.00402832, -0.00320435, ...,  0.00079346,
#           0.00158691, -0.00039673], dtype=float32),
#   'Fear',
#   11],
#  [array([ 0.00701904,  0.00701904,  0.00723267, ..., -0.00042725,
#          -0.00088501, -0.00067139], dtype=float32),
#   'Boredom',
#   11],
#  [array([ 0.        ,  0.00012207,  0.00012207, ..., -0.00521851,
#          -0.00521851, -0.00537109], dtype=float32),
#   'Neutral',
#   11],
#  [array([ 0.00048828, -0.00100708, -0.00048828, ..., -0.00100708,
#          -0.00152588,  0.        ], dtype=float32),
#   'Sadness',
#   11],
#  [array([ 1.5258789e-04,  2.1362305e-04,  6.1035156e-05, ...,
#          -4.5776367e-04, -5.4931641e-04, -4.8828125e-04], dtype=float32),
#   'Anger',
#   11],
#  [array([ 3.0517578e-05,  9.1552734e-05, -3.0517578e-05, ...,
#          -5.4931641e-04, -3.0517578e-04, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   12],
#  [array([0.00445557, 0.00521851, 0.00491333, ..., 0.        , 0.        ,
#          0.        ], dtype=float32),
#   'Boredom',
#   12],
#  [array([ 0.00073242,  0.00073242,  0.00073242, ...,  0.00012207,
#          -0.00024414, -0.00012207], dtype=float32),
#   'Neutral',
#   12],
#  [array([ 3.0517578e-05, -3.0517578e-05,  0.0000000e+00, ...,
#          -7.3242188e-04, -5.7983398e-04, -3.3569336e-04], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.00106812,  0.00143433,  0.00161743, ..., -0.0038147 ,
#          -0.00653076, -0.00546265], dtype=float32),
#   'Fear',
#   12],
#  [array([-3.7231445e-03, -3.2348633e-03, -2.8991699e-03, ...,
#          -3.3569336e-04, -2.1362305e-04, -9.1552734e-05], dtype=float32),
#   'Disgust',
#   12],
#  [array([-0.00030518, -0.00030518, -0.00030518, ...,  0.00192261,
#           0.00030518, -0.00030518], dtype=float32),
#   'Neutral',
#   12],
#  [array([ 0.0000000e+00, -3.0517578e-05, -8.5449219e-04, ...,
#          -2.1362305e-04,  9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   12],
#  [array([ 3.0517578e-05,  0.0000000e+00, -1.5258789e-04, ...,
#          -3.0517578e-05, -1.5258789e-04,  0.0000000e+00], dtype=float32),
#   'Anger',
#   12],
#  [array([ 1.2207031e-04,  3.0517578e-05, -1.8310547e-04, ...,
#          -2.0751953e-03, -1.4648438e-03, -3.0517578e-05], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.00137329,  0.00164795,  0.00149536, ..., -0.00027466,
#          -0.00012207,  0.        ], dtype=float32),
#   'Fear',
#   12],
#  [array([-0.00292969, -0.00299072, -0.00299072, ..., -0.00213623,
#          -0.00238037, -0.00259399], dtype=float32),
#   'Boredom',
#   12],
#  [array([ 0.00106812,  0.00106812,  0.00067139, ..., -0.00024414,
#           0.        , -0.00015259], dtype=float32),
#   'Neutral',
#   12],
#  [array([ 0.00299072,  0.00271606,  0.00326538, ..., -0.00491333,
#          -0.00598145, -0.00543213], dtype=float32),
#   'Sadness',
#   12],
#  [array([ 6.1035156e-05, -6.1035156e-05, -3.3569336e-04, ...,
#           3.9672852e-04, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.00042725,  0.00256348,  0.0039978 , ..., -0.01589966,
#          -0.01663208, -0.01461792], dtype=float32),
#   'Fear',
#   12],
#  [array([ 0.00088501,  0.00100708,  0.00079346, ..., -0.00680542,
#          -0.00613403, -0.00497437], dtype=float32),
#   'Boredom',
#   12],
#  [array([ 2.7465820e-04,  5.4931641e-04, -1.8310547e-04, ...,
#           0.0000000e+00, -1.8310547e-04, -9.1552734e-05], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.        ,  0.00030518,  0.00091553, ..., -0.01287842,
#          -0.01257324, -0.0116272 ], dtype=float32),
#   'Sadness',
#   12],
#  [array([ 0.0000000e+00, -6.1035156e-05, -6.1035156e-04, ...,
#          -6.1035156e-05,  0.0000000e+00, -6.1035156e-05], dtype=float32),
#   'Anger',
#   12],
#  [array([0.        , 0.        , 0.        , ..., 0.00137329, 0.00137329,
#          0.        ], dtype=float32),
#   'Fear',
#   12],
#  [array([ 9.1552734e-05,  4.2724609e-04,  3.0517578e-04, ...,
#          -9.1552734e-05, -2.1362305e-04,  0.0000000e+00], dtype=float32),
#   'Disgust',
#   12],
#  [array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 9.1552734e-05,
#          1.5258789e-04, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   12],
#  [array([ 6.1035156e-05, -1.5258789e-04, -4.8828125e-04, ...,
#          -4.2724609e-04, -4.2724609e-04, -3.9672852e-04], dtype=float32),
#   'Neutral',
#   12],
#  [array([ 0.0000000e+00, -2.1362305e-04, -1.2207031e-04, ...,
#           6.1035156e-05,  0.0000000e+00, -6.1035156e-05], dtype=float32),
#   'Anger',
#   12],
#  [array([1.5258789e-04, 1.8310547e-04, 2.4414062e-04, ..., 1.5258789e-04,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.00164795,  0.00140381,  0.00158691, ..., -0.00039673,
#          -0.00015259,  0.        ], dtype=float32),
#   'Anger',
#   12],
#  [array([ 0.00012207,  0.00039673,  0.00067139, ..., -0.0005188 ,
#          -0.0005188 , -0.00012207], dtype=float32),
#   'Boredom',
#   12],
#  [array([0.00137329, 0.003479  , 0.0020752 , ..., 0.01907349, 0.02001953,
#          0.01956177], dtype=float32),
#   'Sadness',
#   12],
#  [array([-7.9040527e-03, -8.0261230e-03, -8.2397461e-03, ...,
#          -9.1552734e-05,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'Fear',
#   12],
#  [array([ 0.        , -0.00021362, -0.00045776, ..., -0.00045776,
#          -0.00045776, -0.00094604], dtype=float32),
#   'Sadness',
#   12],
#  [array([ 3.6621094e-04,  4.8828125e-04,  5.1879883e-04, ...,
#           0.0000000e+00, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   12],
#  [array([-0.00241089, -0.00241089, -0.00268555, ...,  0.00411987,
#           0.00320435,  0.003479  ], dtype=float32),
#   'Fear',
#   12],
#  [array([ 0.        , -0.00036621, -0.00036621, ..., -0.00100708,
#          -0.00091553, -0.00027466], dtype=float32),
#   'Boredom',
#   12],
#  [array([ 3.0517578e-05, -3.0517578e-05, -9.1552734e-05, ...,
#          -6.1035156e-05, -6.1035156e-05, -9.1552734e-05], dtype=float32),
#   'Anger',
#   12],
#  [array([ 2.1362305e-04,  1.2207031e-04,  9.1552734e-05, ...,
#          -3.5095215e-03, -1.0375977e-03, -1.2390137e-02], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.        , -0.00036621,  0.        , ...,  0.00622559,
#           0.00662231,  0.00662231], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 0.00119019,  0.0015564 ,  0.00259399, ..., -0.01525879,
#          -0.01525879, -0.01577759], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 9.1552734e-05, -3.0517578e-05,  3.0517578e-05, ...,
#           4.8828125e-04,  3.0517578e-04,  2.4414062e-04], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.        , -0.00064087, -0.00064087, ..., -0.01229858,
#          -0.01794434, -0.00332642], dtype=float32),
#   'Boredom',
#   13],
#  [array([-0.00460815, -0.00396729, -0.00372314, ..., -0.00372314,
#          -0.00262451, -0.00085449], dtype=float32),
#   'Neutral',
#   13],
#  [array([ 0.0000000e+00, -3.9672852e-04, -7.3242188e-04, ...,
#           3.0517578e-04,  9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   13],
#  [array([ 0.01062012,  0.01010132,  0.00994873, ...,  0.00082397,
#           0.        , -0.00015259], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.        ,  0.00012207,  0.        , ..., -0.00039673,
#          -0.00012207,  0.        ], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 0.00161743,  0.00161743,  0.00167847, ..., -0.00161743,
#          -0.00067139, -0.00082397], dtype=float32),
#   'Happiness',
#   13],
#  [array([0.01501465, 0.01425171, 0.01501465, ..., 0.00076294, 0.00100708,
#          0.        ], dtype=float32),
#   'Boredom',
#   13],
#  [array([ 0.0138855 ,  0.01416016,  0.0133667 , ..., -0.0005188 ,
#          -0.00024414,  0.        ], dtype=float32),
#   'Neutral',
#   13],
#  [array([ 0.04434204,  0.04467773,  0.04336548, ..., -0.00454712,
#          -0.0022583 , -0.00064087], dtype=float32),
#   'Sadness',
#   13],
#  [array([ 6.1035156e-05,  6.1035156e-05, -6.1035156e-05, ...,
#           0.0000000e+00, -1.5258789e-04,  0.0000000e+00], dtype=float32),
#   'Anger',
#   13],
#  [array([ 0.        ,  0.        , -0.00042725, ...,  0.00012207,
#           0.00027466,  0.        ], dtype=float32),
#   'Fear',
#   13],
#  [array([ 1.3732910e-03,  1.6174316e-03, -9.1552734e-05, ...,
#           4.5776367e-04,  9.1552734e-05, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.00012207, -0.00137329, -0.00247192, ...,  0.00759888,
#          -0.00222778, -0.00537109], dtype=float32),
#   'Boredom',
#   13],
#  [array([-0.01184082, -0.01116943, -0.01248169, ...,  0.00195312,
#          -0.00064087, -0.00030518], dtype=float32),
#   'Sadness',
#   13],
#  [array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.1362305e-04,
#          6.1035156e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   13],
#  [array([ 0.        ,  0.00039673,  0.00039673, ...,  0.00061035,
#          -0.00018311, -0.00039673], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.00158691,  0.00024414, -0.0005188 , ..., -0.00079346,
#          -0.00106812, -0.00079346], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 0.00210571,  0.00531006, -0.00228882, ...,  0.        ,
#          -0.0005188 , -0.0005188 ], dtype=float32),
#   'Boredom',
#   13],
#  [array([ 0.        , -0.00015259,  0.        , ..., -0.00076294,
#          -0.00061035, -0.00061035], dtype=float32),
#   'Neutral',
#   13],
#  [array([-0.03799438, -0.04031372, -0.03955078, ..., -0.00036621,
#          -0.00036621, -0.00076294], dtype=float32),
#   'Sadness',
#   13],
#  [array([ 0.00024414, -0.00012207, -0.00036621, ..., -0.00131226,
#          -0.0010376 , -0.00076294], dtype=float32),
#   'Anger',
#   13],
#  [array([ 3.6621094e-04,  1.2817383e-03,  2.4414062e-04, ...,
#          -2.4414062e-04, -3.0517578e-05, -3.3569336e-04], dtype=float32),
#   'Anger',
#   13],
#  [array([ 4.8828125e-04,  5.4931641e-04,  3.9672852e-04, ...,
#           1.8310547e-04,  9.1552734e-05, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   13],
#  [array([-0.00201416, -0.00222778, -0.00201416, ..., -0.00283813,
#          -0.00305176, -0.00039673], dtype=float32),
#   'Boredom',
#   13],
#  [array([ 0.        , -0.00198364, -0.00170898, ...,  0.00054932,
#          -0.00054932,  0.        ], dtype=float32),
#   'Neutral',
#   13],
#  [array([ 0.        ,  0.00109863, -0.00036621, ..., -0.03924561,
#          -0.03887939, -0.04217529], dtype=float32),
#   'Sadness',
#   13],
#  [array([ 0.0000000e+00,  6.1035156e-05,  4.2724609e-04, ...,
#          -1.2207031e-04,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   13],
#  [array([-0.00314331, -0.003479  , -0.00280762, ..., -0.01290894,
#          -0.01373291, -0.01358032], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.00024414, -0.0005188 , -0.00076294, ..., -0.00076294,
#          -0.00183105, -0.0015564 ], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 0.        ,  0.        , -0.00015259, ...,  0.        ,
#           0.        , -0.00015259], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.00024414,  0.00036621,  0.00036621, ..., -0.0010376 ,
#          -0.00354004, -0.00567627], dtype=float32),
#   'Boredom',
#   13],
#  [array([ 0.00030518,  0.        , -0.00030518, ..., -0.00906372,
#          -0.00842285, -0.00808716], dtype=float32),
#   'Neutral',
#   13],
#  [array([-2.4719238e-03, -2.4719238e-03, -2.4719238e-03, ...,
#           2.4414062e-04,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   13],
#  [array([ 9.1552734e-05,  9.1552734e-05,  9.1552734e-05, ...,
#          -1.8310547e-04, -3.0517578e-04, -5.1879883e-04], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.        , -0.00018311,  0.00018311, ..., -0.0177002 ,
#          -0.0177002 , -0.01791382], dtype=float32),
#   'Boredom',
#   13],
#  [array([-0.00180054, -0.00088501, -0.00088501, ...,  0.00027466,
#           0.        ,  0.        ], dtype=float32),
#   'Neutral',
#   13],
#  [array([2.4414062e-04, 5.7983398e-04, 1.5258789e-04, ..., 2.1362305e-04,
#          3.0517578e-05, 3.0517578e-05], dtype=float32),
#   'Anger',
#   13],
#  [array([ 0.00073242,  0.00073242,  0.        , ..., -0.00466919,
#          -0.00540161, -0.00588989], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.00027466, -0.00012207,  0.00012207, ..., -0.00027466,
#          -0.00012207,  0.        ], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 4.5776367e-04,  3.9672852e-04, -1.2207031e-04, ...,
#          -6.1035156e-05,  1.2207031e-04,  0.0000000e+00], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.        ,  0.00018311, -0.00018311, ...,  0.02090454,
#           0.02069092,  0.02069092], dtype=float32),
#   'Boredom',
#   13],
#  [array([0.00210571, 0.00140381, 0.0010376 , ..., 0.        , 0.0010376 ,
#          0.        ], dtype=float32),
#   'Neutral',
#   13],
#  [array([0.00082397, 0.00039673, 0.00082397, ..., 0.00082397, 0.00082397,
#          0.00210571], dtype=float32),
#   'Sadness',
#   13],
#  [array([ 0.00036621, -0.00119019, -0.00119019, ...,  0.00054932,
#           0.00048828,  0.00042725], dtype=float32),
#   'Anger',
#   13],
#  [array([-0.00357056, -0.00418091, -0.00418091, ...,  0.00057983,
#          -0.00027466,  0.        ], dtype=float32),
#   'Fear',
#   13],
#  [array([ 0.        , -0.00054932, -0.00100708, ..., -0.01071167,
#          -0.01098633, -0.01025391], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 0.00033569,  0.0005188 ,  0.00067139, ..., -0.00033569,
#          -0.00024414, -0.00015259], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.00030518,  0.        ,  0.        , ..., -0.00045776,
#           0.        , -0.00015259], dtype=float32),
#   'Happiness',
#   13],
#  [array([ 0.01126099,  0.0116272 ,  0.0116272 , ...,  0.00015259,
#           0.00015259, -0.00015259], dtype=float32),
#   'Boredom',
#   13],
#  [array([ 0.00021362,  0.        , -0.00137329, ..., -0.00112915,
#          -0.00045776, -0.00067139], dtype=float32),
#   'Neutral',
#   13],
#  [array([ 0.0000000e+00, -6.1035156e-05,  0.0000000e+00, ...,
#          -3.3569336e-04, -2.7465820e-04, -1.2207031e-04], dtype=float32),
#   'Anger',
#   13],
#  [array([-0.00405884, -0.00427246, -0.00405884, ...,  0.00119019,
#           0.00119019,  0.0010376 ], dtype=float32),
#   'Disgust',
#   13],
#  [array([ 5.6457520e-03,  2.1972656e-03, -3.3569336e-03, ...,
# ...
#           0.0000000e+00,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   15],
#  [array([-0.00045776, -0.00045776, -0.00045776, ..., -0.00091553,
#          -0.00094604, -0.00091553], dtype=float32),
#   'Anger',
#   15],
#  [array([ 0.0000000e+00, -6.1035156e-05, -6.1035156e-05, ...,
#           3.1127930e-03,  3.4484863e-03,  3.3874512e-03], dtype=float32),
#   'Disgust',
#   15],
#  [array([6.1035156e-05, 5.1879883e-04, 9.4604492e-04, ..., 2.4414062e-04,
#          1.8310547e-04, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   15],
#  [array([3.5400391e-03, 3.6315918e-03, 4.2419434e-03, ..., 4.2724609e-04,
#          6.1035156e-05, 0.0000000e+00], dtype=float32),
#   'Boredom',
#   15],
#  [array([ 0.00036621,  0.00045776,  0.00094604, ..., -0.00045776,
#          -0.00018311, -0.00027466], dtype=float32),
#   'Neutral',
#   15],
#  [array([-4.5776367e-04, -4.5776367e-04, -4.5776367e-04, ...,
#          -3.0517578e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   15],
#  [array([ 3.0517578e-05,  1.5258789e-04,  3.3569336e-04, ...,
#           8.2397461e-04,  5.1879883e-04, -9.1552734e-05], dtype=float32),
#   'Fear',
#   15],
#  [array([-0.00787354, -0.0072937 , -0.00772095, ...,  0.00039673,
#           0.00039673,  0.        ], dtype=float32),
#   'Disgust',
#   15],
#  [array([-0.00082397, -0.00082397, -0.00076294, ..., -0.00027466,
#          -0.00067139, -0.00012207], dtype=float32),
#   'Happiness',
#   15],
#  [array([ 9.1552734e-05,  1.5258789e-04, -7.6293945e-04, ...,
#           4.5776367e-04, -1.4648438e-03, -5.1879883e-04], dtype=float32),
#   'Happiness',
#   15],
#  [array([ 0.00030518, -0.00061035, -0.00082397, ..., -0.00262451,
#          -0.01126099, -0.00747681], dtype=float32),
#   'Boredom',
#   15],
#  [array([ 0.        ,  0.        ,  0.00036621, ...,  0.00054932,
#           0.00076294, -0.00018311], dtype=float32),
#   'Neutral',
#   15],
#  [array([ 0.00137329, -0.00415039, -0.00415039, ...,  0.00027466,
#           0.00027466, -0.00054932], dtype=float32),
#   'Disgust',
#   15],
#  [array([ 0.00067139,  0.00341797,  0.00436401, ..., -0.00326538,
#          -0.00244141, -0.00094604], dtype=float32),
#   'Boredom',
#   15],
#  [array([-0.00744629, -0.00732422, -0.00732422, ...,  0.00024414,
#           0.00036621,  0.        ], dtype=float32),
#   'Neutral',
#   15],
#  [array([ 0.0000000e+00,  0.0000000e+00,  3.0517578e-05, ...,
#          -3.0517578e-05, -3.0517578e-05, -4.5776367e-04], dtype=float32),
#   'Anger',
#   15],
#  [array([6.1035156e-05, 1.2207031e-04, 0.0000000e+00, ..., 2.1362305e-04,
#          2.1362305e-04, 0.0000000e+00], dtype=float32),
#   'Fear',
#   15],
#  [array([ 0.00012207, -0.00042725, -0.00027466, ..., -0.00424194,
#          -0.00527954, -0.0027771 ], dtype=float32),
#   'Boredom',
#   15],
#  [array([ 0.00012207, -0.00024414, -0.00012207, ...,  0.00061035,
#           0.00048828,  0.        ], dtype=float32),
#   'Neutral',
#   15],
#  [array([0.00048828, 0.00085449, 0.00033569, ..., 0.02203369, 0.02545166,
#          0.01754761], dtype=float32),
#   'Sadness',
#   15],
#  [array([ 2.1362305e-04,  3.9672852e-04,  6.1035156e-05, ...,
#           3.0517578e-05, -3.0517578e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   15],
#  [array([ 3.0517578e-05,  9.1552734e-05, -1.2207031e-04, ...,
#          -3.0517578e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'Anger',
#   15],
#  [array([ 6.1035156e-05, -3.3569336e-04, -5.1879883e-04, ...,
#          -6.7443848e-03, -5.5847168e-03, -3.4179688e-03], dtype=float32),
#   'Fear',
#   15],
#  [array([ 0.        , -0.00012207, -0.00057983, ...,  0.00012207,
#          -0.00042725,  0.        ], dtype=float32),
#   'Boredom',
#   15],
#  [array([ 0.00106812,  0.00015259, -0.00183105, ...,  0.00045776,
#          -0.00015259,  0.        ], dtype=float32),
#   'Neutral',
#   15],
#  [array([ 0.01092529, -0.00949097, -0.01504517, ...,  0.00805664,
#           0.00839233,  0.00805664], dtype=float32),
#   'Sadness',
#   15],
#  [array([2.1362305e-04, 8.5449219e-04, 1.8310547e-04, ..., 1.2207031e-04,
#          9.1552734e-05, 0.0000000e+00], dtype=float32),
#   'Anger',
#   15],
#  [array([2.1362305e-04, 6.1035156e-05, 6.1035156e-05, ..., 3.6621094e-04,
#          3.6621094e-04, 2.7465820e-04], dtype=float32),
#   'Anger',
#   15],
#  [array([ 0.00100708, -0.00143433,  0.00274658, ..., -0.00042725,
#          -0.00012207,  0.        ], dtype=float32),
#   'Fear',
#   15],
#  [array([ 9.1552734e-05, -9.1552734e-05, -3.0517578e-04, ...,
#          -3.0517578e-05, -1.5258789e-04, -9.1552734e-05], dtype=float32),
#   'Happiness',
#   15],
#  [array([ 0.        ,  0.00109863,  0.0010376 , ...,  0.00024414,
#           0.00036621, -0.00067139], dtype=float32),
#   'Boredom',
#   15],
#  [array([-0.00558472, -0.00598145, -0.00698853, ..., -0.0032959 ,
#          -0.0032959 , -0.00317383], dtype=float32),
#   'Neutral',
#   15],
#  [array([ 9.1552734e-05, -9.1552734e-05, -3.3569336e-04, ...,
#          -5.4016113e-03, -4.8522949e-03, -2.0751953e-03], dtype=float32),
#   'Sadness',
#   15],
#  [array([ 1.2207031e-04,  1.2207031e-04,  9.1552734e-05, ...,
#           9.1552734e-05,  0.0000000e+00, -9.1552734e-05], dtype=float32),
#   'Anger',
#   15],
#  [array([2.0141602e-03, 3.3569336e-03, 2.4414062e-04, ..., 6.1035156e-05,
#          0.0000000e+00, 0.0000000e+00], dtype=float32),
#   'Fear',
#   15],
#  [array([ 0.00030518,  0.00061035,  0.0010376 , ..., -0.00894165,
#          -0.01107788, -0.01107788], dtype=float32),
#   'Boredom',
#   15],
#  [array([-0.01150513, -0.012146  , -0.01083374, ...,  0.00085449,
#          -0.00064087, -0.00064087], dtype=float32),
#   'Neutral',
#   15],
#  [array([ 0.        , -0.00027466, -0.00073242, ..., -0.00469971,
#          -0.00366211, -0.00396729], dtype=float32),
#   'Neutral',
#   15],
#  [array([-0.00085449, -0.00085449, -0.00088501, ..., -0.00042725,
#          -0.00036621, -0.00030518], dtype=float32),
#   'Anger',
#   15],
#  [array([-9.1552734e-05, -9.1552734e-05, -1.8310547e-04, ...,
#          -2.4414062e-03, -1.4343262e-03, -4.8828125e-04], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.00286865,  0.00286865, -0.00152588, ...,  0.        ,
#          -0.00018311,  0.        ], dtype=float32),
#   'Happiness',
#   16],
#  [array([-1.0375977e-03, -1.3122559e-03, -1.4648438e-03, ...,
#           1.0681152e-03,  7.9345703e-04, -9.1552734e-05], dtype=float32),
#   'Boredom',
#   16],
#  [array([-0.00534058, -0.00567627, -0.00552368, ...,  0.00567627,
#           0.00421143, -0.00274658], dtype=float32),
#   'Neutral',
#   16],
#  [array([ 0.00119019,  0.00192261,  0.00534058, ..., -0.01119995,
#          -0.01022339, -0.01022339], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 0.00057983, -0.00048828, -0.00097656, ..., -0.00036621,
#          -0.00057983, -0.00057983], dtype=float32),
#   'Anger',
#   16],
#  [array([-0.00134277, -0.00125122, -0.00119019, ..., -0.00149536,
#          -0.00094604, -0.00088501], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.00061035,  0.00137329,  0.00106812, ...,  0.00061035,
#           0.00015259, -0.00045776], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.00131226,  0.00076294,  0.00045776, ..., -0.00256348,
#          -0.00616455, -0.00064087], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.00131226,  0.00012207, -0.0005188 , ..., -0.00024414,
#          -0.00091553, -0.00024414], dtype=float32),
#   'Neutral',
#   16],
#  [array([ 0.00408936,  0.00289917,  0.00115967, ..., -0.00582886,
#          -0.00057983, -0.00115967], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 0.0000000e+00, -6.1035156e-05, -1.2207031e-04, ...,
#          -6.1035156e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   16],
#  [array([-0.00125122, -0.00131226, -0.00125122, ...,  0.00375366,
#           0.00344849,  0.00344849], dtype=float32),
#   'Fear',
#   16],
#  [array([ 0.        , -0.00039673, -0.00039673, ...,  0.00518799,
#           0.00265503, -0.00146484], dtype=float32),
#   'Disgust',
#   16],
#  [array([6.1035156e-05, 4.5776367e-04, 3.3569336e-04, ..., 6.1035156e-05,
#          1.2207031e-04, 0.0000000e+00], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 0.00024414,  0.00012207, -0.00024414, ..., -0.00567627,
#          -0.00418091, -0.00439453], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 1.8615723e-03,  1.3427734e-03,  3.9672852e-04, ...,
#           2.1667480e-03, -1.8310547e-04, -9.1552734e-05], dtype=float32),
#   'Boredom',
#   16],
#  [array([-0.00015259,  0.00064087, -0.00015259, ...,  0.00079346,
#           0.00045776, -0.00030518], dtype=float32),
#   'Neutral',
#   16],
#  [array([ 0.0005188 , -0.00210571, -0.00900269, ..., -0.0105896 ,
#          -0.0105896 , -0.00424194], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 0.0000000e+00, -1.2207031e-04, -1.2207031e-04, ...,
#           1.2207031e-04, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([ 8.2397461e-04,  5.1879883e-04, -7.0190430e-04, ...,
#          -6.1035156e-05, -1.2207031e-04, -6.1035156e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([ 1.2207031e-04,  2.1362305e-04,  0.0000000e+00, ...,
#           6.1035156e-05, -6.1035156e-05, -2.1362305e-04], dtype=float32),
#   'Fear',
#   16],
#  [array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           1.8310547e-04,  1.5258789e-04, -3.0517578e-05], dtype=float32),
#   'Disgust',
#   16],
#  [array([0.00036621, 0.00045776, 0.00057983, ..., 0.00012207, 0.00024414,
#          0.        ], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 2.1362305e-04,  4.2724609e-04,  1.5258789e-04, ...,
#           2.6855469e-03,  1.9226074e-03, -3.0517578e-05], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.00125122, -0.00253296, -0.0038147 , ...,  0.00125122,
#           0.00253296,  0.00125122], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 0.0012207 ,  0.0012207 , -0.00088501, ..., -0.00015259,
#           0.00015259,  0.        ], dtype=float32),
#   'Anger',
#   16],
#  [array([2.1362305e-04, 2.7465820e-04, 0.0000000e+00, ..., 6.1035156e-05,
#          6.1035156e-05, 6.1035156e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([ 9.1552734e-05, -1.8310547e-04, -1.8310547e-04, ...,
#           1.1901855e-03, -9.1552734e-05, -1.8310547e-04], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.0012207 ,  0.00613403,  0.00714111, ..., -0.00030518,
#          -0.0005188 , -0.00015259], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 1.5258789e-04,  1.5258789e-04, -2.7465820e-04, ...,
#          -3.0517578e-05, -3.0517578e-05, -1.2207031e-04], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 0.00021362, -0.00042725, -0.00085449, ..., -0.00042725,
#          -0.00042725, -0.00042725], dtype=float32),
#   'Boredom',
#   16],
#  [array([-0.00177002, -0.00164795, -0.00198364, ..., -0.00265503,
#          -0.00286865, -0.00109863], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.00030518, -0.00064087, -0.00030518, ..., -0.00289917,
#          -0.0045166 , -0.00320435], dtype=float32),
#   'Neutral',
#   16],
#  [array([-0.0005188 , -0.0005188 , -0.00317383, ...,  0.00634766,
#           0.01113892,  0.00689697], dtype=float32),
#   'Sadness',
#   16],
#  [array([-3.9672852e-04, -3.9672852e-04, -2.4414062e-04, ...,
#          -6.1035156e-05, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([ 9.1552734e-05, -3.0517578e-04, -7.9345703e-04, ...,
#          -1.2207031e-03, -1.4343262e-03, -1.5258789e-03], dtype=float32),
#   'Fear',
#   16],
#  [array([ 1.5258789e-04,  1.5258789e-04, -3.3569336e-04, ...,
#          -2.4414062e-04, -6.1035156e-05, -1.5258789e-04], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 1.5258789e-04,  5.7983398e-04,  4.5776367e-04, ...,
#          -3.0517578e-05,  3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'Happiness',
#   16],
#  [array([0.        , 0.00082397, 0.00015259, ..., 0.00030518, 0.00082397,
#          0.00048828], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.01272583,  0.00500488,  0.00369263, ..., -0.00054932,
#          -0.00054932, -0.00054932], dtype=float32),
#   'Boredom',
#   16],
#  [array([0.00219727, 0.00384521, 0.00497437, ..., 0.01049805, 0.01159668,
#          0.01049805], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 5.7983398e-04, -8.2397461e-04, -1.7700195e-03, ...,
#          -9.1552734e-05, -9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   16],
#  [array([ 2.1362305e-04,  7.3242188e-04,  4.2724609e-04, ...,
#          -1.8310547e-04, -9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   16],
#  [array([ 0.0005188 ,  0.00057983,  0.00021362, ..., -0.00091553,
#          -0.00106812, -0.00097656], dtype=float32),
#   'Fear',
#   16],
#  [array([ 2.7465820e-04,  4.8828125e-04, -9.1552734e-05, ...,
#           7.0190430e-04,  3.9672852e-04, -1.8310547e-04], dtype=float32),
#   'Disgust',
#   16],
#  [array([-6.1035156e-05, -2.4414062e-04, -1.5258789e-04, ...,
#          -3.3569336e-04, -3.3569336e-04, -3.9672852e-04], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 0.00054932, -0.00119019, -0.00158691, ..., -0.00192261,
#          -0.00247192, -0.00158691], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 3.0517578e-05,  3.0517578e-05,  3.0517578e-05, ...,
#          -9.1552734e-05, -1.5258789e-04, -3.0517578e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([-0.00018311, -0.00030518, -0.00024414, ...,  0.00082397,
#          -0.00030518, -0.00234985], dtype=float32),
#   'Fear',
#   16],
#  [array([0.0007019 , 0.0012207 , 0.0012207 , ..., 0.0010376 , 0.00094604,
#          0.0012207 ], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.0000000e+00, -3.0517578e-05, -6.1035156e-05, ...,
#          -3.0517578e-05, -6.1035156e-05, -3.0517578e-05], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 3.0517578e-04, -3.0517578e-05, -1.5258789e-04, ...,
#          -3.9672852e-04, -4.8828125e-04, -4.2724609e-04], dtype=float32),
#   'Happiness',
#   16],
#  [array([ 0.00018311, -0.00115967, -0.00076294, ...,  0.00128174,
#          -0.00027466, -0.00057983], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.00091553,  0.00164795,  0.00018311, ..., -0.00073242,
#          -0.00036621, -0.00018311], dtype=float32),
#   'Neutral',
#   16],
#  [array([ 0.00021362,  0.00085449, -0.00128174, ..., -0.00588989,
#          -0.00390625, -0.00436401], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 6.1035156e-05,  6.1035156e-05, -1.8310547e-04, ...,
#          -5.1879883e-04, -2.4414062e-04, -4.2724609e-04], dtype=float32),
#   'Anger',
#   16],
#  [array([ 0.0000000e+00, -6.1035156e-05,  0.0000000e+00, ...,
#          -2.7465820e-04, -1.8310547e-04, -6.1035156e-05], dtype=float32),
#   'Fear',
#   16],
#  [array([-0.00012207, -0.00021362, -0.00012207, ..., -0.00143433,
#          -0.00137329, -0.00161743], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 9.1552734e-05, -1.8310547e-04, -7.9345703e-04, ...,
#          -4.8828125e-04, -1.8310547e-04,  0.0000000e+00], dtype=float32),
#   'Happiness',
#   16],
#  [array([-0.00323486, -0.00338745, -0.00366211, ..., -0.00012207,
#          -0.00216675, -0.00244141], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 0.00073242,  0.00024414,  0.00067139, ...,  0.00219727,
#          -0.00033569, -0.00045776], dtype=float32),
#   'Boredom',
#   16],
#  [array([ 2.9907227e-03,  4.5166016e-03, -8.8500977e-04, ...,
#          -6.1035156e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'Anger',
#   16],
#  [array([-0.00164795, -0.00210571, -0.00180054, ...,  0.00073242,
#           0.00042725,  0.        ], dtype=float32),
#   'Fear',
#   16],
#  [array([ 1.5258789e-04,  6.7138672e-04,  1.7395020e-03, ...,
#          -9.1552734e-05, -9.1552734e-05, -2.1362305e-04], dtype=float32),
#   'Disgust',
#   16],
#  [array([ 0.        , -0.00012207, -0.00079346, ...,  0.0012207 ,
#           0.0012207 ,  0.00119019], dtype=float32),
#   'Happiness',
#   16],
#  [array([-6.1035156e-05,  3.9672852e-04,  0.0000000e+00, ...,
#           1.2817383e-03, -1.2207031e-04, -1.2207031e-04], dtype=float32),
#   'Boredom',
#   16],
#  [array([-0.00784302, -0.00869751, -0.00900269, ...,  0.00085449,
#           0.00085449, -0.00057983], dtype=float32),
#   'Sadness',
#   16],
#  [array([0.01080322, 0.01156616, 0.00924683, ..., 0.00152588, 0.00048828,
#          0.00100708], dtype=float32),
#   'Sadness',
#   16],
#  [array([ 3.0517578e-04,  5.7983398e-04, -4.5776367e-04, ...,
#          -6.1035156e-05, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'Anger',
#   16],
#  [array([ 0.00030518,  0.00076294,  0.00030518, ..., -0.00015259,
#           0.        ,  0.        ], dtype=float32),
#   'Anger',
#   16]]
