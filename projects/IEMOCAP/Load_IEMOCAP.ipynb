# %% [markdown]
# # IEMOCAPをロードする
#
# - IEMOCAPのロードをするプログラム
# - 要求: 2個上の階層にIEMOCAP_full_releaseを配置する
# - return: wavファイルとラベルのペア

# %%
import os
import re
from statistics import mode
import collections
import librosa
import math
import audeer
import pandas as pd

# %% [markdown]
# ## 前準備

# %% [markdown]
# #### グローバルパスの定義

# %%
# 上位パスを排除してファイル名だけ見せる関数
def display_filename(filename, path_splitter='/'):
    return filename[filename.rfind(path_splitter) + 1:]

# %%
# wavファイルがセッションごとに整理されてるディレクトリへのパス
session_dirs = ['../../IEMOCAP_full_release/' + 'Session' + str(i) + '/' + 'sentences/wav/' for i in range(1, 6)]
# ラベルがセッションごとに整理されてるディレクトリへのパス
label_dirs = ['../../IEMOCAP_full_release/' + 'Session' + str(i) + '/dialog/EmoEvaluation/Categorical/' for i in range(1, 6)]

# %% [markdown]
# #### 1つ1つのwavファイルへのパスを取る

# %%
# 変数定義，ペアレントディレクトリへのパスを取っておく
wav_file_paths_p = []
for ses_d in session_dirs:
    sentence_dirs = sorted(os.listdir(ses_d))
    for sent_d in sentence_dirs:
        wav_file_paths.append(os.path.join(ses_d, sent_d))
        wav_file_paths_p.append(os.path.join(ses_d, sent_d))

# %%
# 不要な.DS_Storeとかいうのが出てきたので削除
for path in wav_file_paths_p:
    if 'DS_Store' in path:
        wav_file_paths_p.remove(path)

# %%
# 1つ1つのwavファイルへのパスを取流
wav_file_paths = []
for path in wav_file_paths_p:
    filenames = sorted(os.listdir(path))
    for f in filenames:
        wav_file_paths.append(os.path.join(path, f))

# %%
# wav以外の拡張子のファイルが含まれてたら削除
for path in wav_file_paths:
    base, ext = os.path.splitext(path)
    if not ext == '.wav':
        wav_file_paths.remove(path)

# %%
# 拡張子を除いたverのファイル名も取っておく
filenames = [audeer.basename_wo_ext(p) for p in wav_file_paths]

# %% [markdown]
# ## 1つ1つのファイルのラベルを作る
#
# wavファイルそれぞれにつき，3人の評価者がラベル付をしている．
# 1. wavファイルそれぞれについてラベルファイルを参照し，3人のラベル付を取得する．話者の情報もこのときに取っておく.
# 1. HappinessとExcitedのラベルをマージする(感情価ValenceとActivationの値が近いため)
# 1. 多数決を取ってwavファイルに対するラベルを決定する
# 1. Happiness, Anger, Neutral, Sadnessだけ抽出する

# %% [markdown]
# #### 1: wavファイルそれぞれについてラベルファイルを参照し，3人のラベル付を取得する

# %%
# ラベル付けファイル1つ1つへのpathをとる
label_file_paths = []
for label_dir in label_dirs:
    label_files_ = sorted(os.listdir(label_dir))
    for f in label_files_:
        base, ext = os.path.splitext(f)
        if ext == '.txt':
            label_file_paths.append(os.path.join(label_dir, f))

# %%
# Ses01F_impro01という1つのトークダイアログに，e2, e3, e4という3人の評価者によるラベル付けがされている
# Ses01F_impro02という1つのトークダイアログに，e1, e3, e4という3人の評価者によるラベル付けがされている
label_file_paths[:6]
# Out:
# ['../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro01_e2_cat.txt',
#  '../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro01_e3_cat.txt',
#  '../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro01_e4_cat.txt',
#  '../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro02_e1_cat.txt',
#  '../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro02_e3_cat.txt',
#  '../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/Ses01F_impro02_e4_cat.txt']

# %%
# 全てのラベルファイルを参照し，1つ1つのwavにラベルをつける
# 1つ1つの発話ののラベルはスピーチダイアログごとにtxtファイルを作って管理されている
# スピーチダイアログの名前とwavのペアレントディレクトリの名前は一致する

# 上位パスを排除して名前だけのwav_file_path_pを作る
wav_file_paths_pp = []

for path in wav_file_paths_p:
    wav_file_paths_pp.append(path[path.rfind('/') + 1: ])

# %%
# list内のkeyを含む要素を全て返す関数
def index_multi(lst, key):
    idxes = []
    for i in range(len(lst)):
        # print(f'examining {lst[i]} for key:{key}')
        if key in lst[i]:
            idxes.append(i)
    return idxes

# %%
# スピーチダイアログごとに評価ファイルを分けていく
# 1つのダイアログに複数の評価者がいる

label_file_indexes = []
for dirname in wav_file_paths_pp:
    idxes = index_multi(label_file_paths, dirname)
    label_file_indexes.append(idxes)

# %%
speaker_mapping = {
    'Ses01M' : 1,
    'Ses01F' : 2, 
    'Ses02M': 3,
    'Ses02F' :4,
    'Ses03M': 5,
    'Ses03F': 6,
    'Ses04M': 7,
    'Ses04F': 8,
    'Ses05M': 9,
    'Ses05F': 10
}

# %%
def identify_speaker(filename):
    print(filename)
    session = filename[:5]
    sex = filename[-4]
    return session + sex

# %%
# 各音声ファイルごとにラベルを作っていく
# 同じダイアログに対する複数の評価者のラベル付を同時に読み込んで多数決を行う
raw_labels = []
speakers = []
filenames = []
for i, indexes in enumerate(label_file_indexes):
    # ここで1ダイアログの処理
    # それぞれの評価ファイルのラベルを保存しておくグローバルリスト
    global_labels = []
    
    # それぞれの評価ファイルのラベルを読み込んでglobal_labelsに保存する
    for index in indexes: 
        # ここで1ファイルの処理
        file = open(label_file_paths[index], 'r')
        local_labels = []
        print(f'#{display_filename(wav_file_paths_pp[i])}: opening {display_filename(label_file_paths[index])}')
        for line in file:
            label = re.split('[:;()]', line)
            label = label[:-1]
            local_labels.append(label)
        global_labels.append(local_labels)
        
    # 1ダイアログに含まれる発話すべてとラベルをまとめて紐づける
    # raw_labelsは複数ラベルのまま使う，maj_labelsは多数決をとる
    for file_id in range(len(global_labels[0])):
        raw_label = [global_labels[i][file_id][1] for i in range(len(global_labels))]
        filename = global_labels[0][file_id][0][:-1]
        filenames.append(filename)
        speakers.append(speaker_mapping[identify_speaker(filename)])
        raw_labels.append(raw_label)
# Out:
# #Ses01F_impro01: opening Ses01F_impro01_e2_cat.txt
# #Ses01F_impro01: opening Ses01F_impro01_e3_cat.txt
# #Ses01F_impro01: opening Ses01F_impro01_e4_cat.txt
# Ses01F_impro01_F000
# Ses01F_impro01_F001
# Ses01F_impro06_M011
# Ses01F_impro06_M012
# Ses01F_impro06_M013
# Ses01F_impro06_M014
# Ses01F_impro06_M015
# Ses01F_impro06_M016
# Ses01F_impro06_M017
# #Ses01F_impro07: opening Ses01F_impro07_e1_cat.txt
# #Ses01F_impro07: opening Ses01F_impro07_e2_cat.txt
# #Ses01F_impro07: opening Ses01F_impro07_e4_cat.txt
# Ses01F_impro07_F000
# Ses01F_impro07_F001
# Ses01F_impro07_F002
# Ses01F_impro07_F003
# Ses01F_impro07_F004
# Ses01F_impro07_F005
# Ses01F_impro07_F006
# Ses01F_impro07_F007
# Ses01F_impro07_F008
# Ses01F_impro07_F009
# Ses01F_impro07_F010
# Ses01F_impro07_F011
# Ses01F_impro07_F012
# Ses01F_impro07_F013
# Ses01F_impro07_F014
# Ses01F_impro07_F015
# Ses01F_impro07_F016
# Ses01F_impro07_M000
# Ses01F_impro07_M001
# Ses01F_impro07_M002
# Ses01F_impro07_M003
# Ses01F_impro07_M004
# Ses01F_impro07_M005
# Ses01F_impro07_M006
# Ses01F_impro07_M007
# Ses01F_impro07_M008
# Ses01F_impro07_M009
# Ses01F_impro07_M010
# Ses01F_impro07_M011
# Ses01F_impro07_M012
# Ses01F_impro07_M013
# Ses01F_impro07_M014
# Ses01F_impro07_M015
# Ses01F_impro07_M016
# Ses01F_impro07_M017
# Ses01F_impro07_M018
# Ses01F_impro07_M019
# #Ses01F_script01_1: opening Ses01F_script01_1_e1_cat.txt
# #Ses01F_script01_1: opening Ses01F_script01_1_e4_cat.txt
# #Ses01F_script01_1: opening Ses01F_script01_1_e5_cat.txt
# Ses01F_script01_1_F000
# Ses01F_script01_1_F001
# Ses01F_script01_1_F002
# Ses01F_script01_1_F003
# Ses01F_script01_1_F004
# Ses01F_script01_1_F005
# Ses01F_script01_1_F006
# Ses01F_script01_1_F007
# Ses01F_script01_1_F008
# Ses01F_script01_1_F009
# Ses01F_script01_1_F010
# Ses01F_script01_1_F011
# Ses01F_script01_1_F012
# Ses01F_script01_1_F013
# Ses01F_script01_1_F014
# Ses01F_script01_1_F015
# Ses01F_script01_1_F016
# Ses01F_script01_1_F017
# Ses01F_script01_1_F018
# Ses01F_script01_1_F019
# Ses01F_script01_1_F020
# Ses01F_script01_1_F021
# Ses01F_script01_1_F022
# Ses01F_script01_1_F023
# Ses01F_script01_1_F024
# Ses01F_script01_1_F025
# Ses01F_script01_1_F026
# Ses01F_script01_1_F027
# Ses01F_script01_1_F028
# Ses01F_script01_1_F029
# Ses01F_script01_1_F030
# Ses01F_script01_1_F031
# Ses01F_script01_1_F032
# Ses01F_script01_1_F033
# Ses01F_script01_1_F034
# Ses01F_script01_1_F035
# Ses01F_script01_1_F036
# Ses01F_script01_1_F037
# Ses01F_script01_1_F038
# Ses01F_script01_1_F039
# Ses01F_script01_1_F040
# Ses01F_script01_1_F041
# Ses01F_script01_1_F042
# Ses01F_script01_1_F043
# Ses01F_script01_1_F044
# Ses01F_script01_1_M000
# Ses01F_script01_1_M001
# Ses01F_script01_1_M002
# Ses01F_script01_1_M003
# Ses01F_script01_1_M004
# Ses01F_script01_1_M005
# Ses01F_script01_1_M006
# Ses01F_script01_1_M007
# Ses01F_script01_1_M008
# Ses01F_script01_1_M009
# Ses01F_script01_1_M010
# Ses01F_script01_1_M011
# Ses01F_script01_1_M012
# Ses01F_script01_1_M013
# Ses01F_script01_1_M014
# Ses01F_script01_1_M015
# Ses01F_script01_1_M016
# Ses01F_script01_1_M017
# Ses01F_script01_1_M018
# Ses01F_script01_1_M019
# Ses01F_script01_1_M020
# Ses01F_script01_1_M021
# Ses01F_script01_1_M022
# Ses01F_script01_1_M023
# Ses01F_script01_1_M024
# Ses01F_script01_1_M025
# Ses01F_script01_1_M026
# Ses01F_script01_1_M027
# Ses01F_script01_1_M028
# Ses01F_script01_1_M029
# Ses01F_script01_1_M030
# Ses01F_script01_1_M031
# Ses01F_script01_1_M032
# Ses01F_script01_1_M033
# Ses01F_script01_1_M034
# Ses01F_script01_1_M035
# Ses01F_script01_1_M036
# Ses01F_script01_1_M037
# Ses01F_script01_1_M038
# Ses01F_script01_1_M039
# Ses01F_script01_1_M040
# Ses01F_script01_1_M041
# Ses01F_script01_1_M042
# Ses01F_script01_1_M043
# #Ses01F_script01_2: opening Ses01F_script01_2_e1_cat.txt
# #Ses01F_script01_2: opening Ses01F_script01_2_e2_cat.txt
# #Ses01F_script01_2: opening Ses01F_script01_2_e4_cat.txt
# Ses01F_script01_2_F000
# Ses01F_script01_2_F001
# Ses01F_script01_2_F002
# Ses01F_script01_2_F003
# Ses01F_script01_2_F004
# Ses01F_script01_2_F005
# Ses01F_script01_2_F006
# Ses01F_script01_2_F007
# Ses01F_script01_2_F008
# Ses01F_script01_2_F009
# Ses01F_script01_2_F010
# Ses01F_script01_2_F011
# Ses01F_script01_2_F012
# Ses01F_script01_2_F013
# Ses01F_script01_2_F014
# Ses01F_script01_2_M000
# Ses01F_script01_2_M001
# Ses01F_script01_2_M002
# Ses01F_script01_2_M003
# Ses01F_script01_2_M004
# Ses01F_script01_2_M005
# Ses01F_script01_2_M006
# Ses01F_script01_2_M007
# Ses01F_script01_2_M008
# Ses01F_script01_2_M009
# Ses01F_script01_2_M010
# Ses01F_script01_2_M011
# Ses01F_script01_2_M012
# Ses01F_script01_2_M013
# Ses01F_script01_2_M014
# Ses01F_script01_2_M015
# Ses01F_script01_2_M016
# Ses01F_script01_2_M017
# #Ses01F_script01_3: opening Ses01F_script01_3_e1_cat.txt
# #Ses01F_script01_3: opening Ses01F_script01_3_e4_cat.txt
# #Ses01F_script01_3: opening Ses01F_script01_3_e5_cat.txt
# Ses01F_script01_3_F000
# Ses01F_script01_3_F001
# Ses01F_script01_3_F002
# Ses01F_script01_3_F003
# Ses01F_script01_3_F004
# Ses01F_script01_3_F005
# Ses01F_script01_3_F006
# Ses01F_script01_3_F007
# Ses01F_script01_3_F008
# Ses01F_script01_3_F009
# Ses01F_script01_3_F010
# Ses01F_script01_3_F011
# Ses01F_script01_3_F012
# Ses01F_script01_3_F013
# Ses01F_script01_3_F014
# Ses01F_script01_3_F015
# Ses01F_script01_3_F016
# Ses01F_script01_3_F017
# Ses01F_script01_3_F018
# Ses01F_script01_3_F019
# Ses01F_script01_3_F020
# Ses01F_script01_3_F021
# Ses01F_script01_3_F022
# Ses01F_script01_3_F023
# Ses01F_script01_3_F024
# Ses01F_script01_3_F025
# Ses01F_script01_3_F026
# Ses01F_script01_3_F027
# Ses01F_script01_3_F028
# Ses01F_script01_3_F029
# Ses01F_script01_3_F030
# Ses01F_script01_3_F031
# Ses01F_script01_3_F032
# Ses01F_script01_3_F033
# Ses01F_script01_3_F034
# Ses01F_script01_3_F035
# Ses01F_script01_3_M000
# Ses01F_script01_3_M001
# Ses01F_script01_3_M002
# Ses01F_script01_3_M003
# Ses01F_script01_3_M004
# Ses01F_script01_3_M005
# Ses01F_script01_3_M006
# Ses01F_script01_3_M007
# Ses01F_script01_3_M008
# Ses01F_script01_3_M009
# Ses01F_script01_3_M010
# Ses01F_script01_3_M011
# Ses01F_script01_3_M012
# Ses01F_script01_3_M013
# Ses01F_script01_3_M014
# Ses01F_script01_3_M015
# Ses01F_script01_3_M016
# Ses01F_script01_3_M017
# Ses01F_script01_3_M018
# Ses01F_script01_3_M019
# Ses01F_script01_3_M020
# Ses01F_script01_3_M021
# Ses01F_script01_3_M022
# Ses01F_script01_3_M023
# Ses01F_script01_3_M024
# Ses01F_script01_3_M025
# Ses01F_script01_3_M026
# Ses01F_script01_3_M027
# Ses01F_script01_3_M028
# Ses01F_script01_3_M029
# Ses01F_script01_3_M030
# Ses01F_script01_3_M031
# Ses01F_script01_3_M032
# Ses01F_script01_3_M033
# Ses01F_script01_3_M034
# Ses01F_script01_3_M035
# Ses01F_script01_3_M036
# Ses01F_script01_3_M037
# Ses01F_script01_3_M038
# #Ses01F_script02_1: opening Ses01F_script02_1_e2_cat.txt
# #Ses01F_script02_1: opening Ses01F_script02_1_e3_cat.txt
# #Ses01F_script02_1: opening Ses01F_script02_1_e4_cat.txt
# Ses01F_script02_1_F000
# Ses01F_script02_1_F001
# Ses01F_script02_1_F002
# Ses01F_script02_1_F003
# Ses01F_script02_1_F004
# Ses01F_script02_1_F005
# Ses01F_script02_1_F006
# Ses01F_script02_1_F007
# Ses01F_script02_1_F008
# Ses01F_script02_1_F009
# Ses01F_script02_1_F010
# Ses01F_script02_1_F011
# Ses01F_script02_1_F012
# Ses01F_script02_1_F013
# Ses01F_script02_1_F014
# Ses01F_script02_1_F015
# Ses01F_script02_1_F016
# Ses01F_script02_1_F017
# Ses01F_script02_1_F018
# Ses01F_script02_1_F019
# Ses01F_script02_1_F020
# Ses01F_script02_1_F021
# Ses01F_script02_1_F022
# Ses01F_script02_1_F023
# Ses01F_script02_1_F024
# Ses01F_script02_1_F025
# Ses01F_script02_1_M000
# Ses01F_script02_1_M001
# Ses01F_script02_1_M002
# Ses01F_script02_1_M003
# Ses01F_script02_1_M004
# Ses01F_script02_1_M005
# Ses01F_script02_1_M006
# Ses01F_script02_1_M007
# Ses01F_script02_1_M008
# Ses01F_script02_1_M009
# Ses01F_script02_1_M010
# Ses01F_script02_1_M011
# Ses01F_script02_1_M012
# Ses01F_script02_1_M013
# Ses01F_script02_1_M014
# Ses01F_script02_1_M015
# Ses01F_script02_1_M016
# Ses01F_script02_1_M017
# Ses01F_script02_1_M018
# Ses01F_script02_1_M019
# Ses01F_script02_1_M020
# Ses01F_script02_1_M021
# Ses01F_script02_1_M022
# Ses01F_script02_1_M023
# Ses01F_script02_1_M024
# Ses01F_script02_1_M025
# Ses01F_script02_1_M026
# Ses01F_script02_1_M027
# Ses01F_script02_1_M028
# Ses01F_script02_1_M029
# Ses01F_script02_1_M030
# Ses01F_script02_1_M031
# Ses01F_script02_1_M032
# Ses01F_script02_1_M033
# Ses01F_script02_1_M034
# Ses01F_script02_1_M035
# Ses01F_script02_1_M036
# Ses01F_script02_1_M037
# Ses01F_script02_1_M038
# Ses01F_script02_1_M039
# Ses01F_script02_1_M040
# Ses01F_script02_1_M041
# Ses01F_script02_1_M042
# Ses01F_script02_1_M043
# Ses01F_script02_1_M044
# #Ses01F_script02_2: opening Ses01F_script02_2_e2_cat.txt
# #Ses01F_script02_2: opening Ses01F_script02_2_e3_cat.txt
# #Ses01F_script02_2: opening Ses01F_script02_2_e4_cat.txt
# Ses01F_script02_2_F000
# Ses01F_script02_2_F001
# Ses01F_script02_2_F002
# Ses01F_script02_2_F003
# Ses01F_script02_2_F004
# Ses01F_script02_2_F005
# Ses01F_script02_2_F006
# Ses01F_script02_2_F007
# Ses01F_script02_2_F008
# Ses01F_script02_2_F009
# Ses01F_script02_2_F010
# Ses01F_script02_2_F011
# Ses01F_script02_2_F012
# Ses01F_script02_2_F013
# Ses01F_script02_2_F014
# Ses01F_script02_2_F015
# Ses01F_script02_2_F016
# Ses01F_script02_2_F017
# Ses01F_script02_2_F018
# Ses01F_script02_2_F019
# Ses01F_script02_2_F020
# Ses01F_script02_2_F021
# Ses01F_script02_2_F022
# Ses01F_script02_2_F023
# Ses01F_script02_2_F024
# Ses01F_script02_2_F025
# Ses01F_script02_2_F026
# Ses01F_script02_2_F027
# Ses01F_script02_2_F028
# Ses01F_script02_2_F029
# Ses01F_script02_2_F030
# Ses01F_script02_2_F031
# Ses01F_script02_2_F032
# Ses01F_script02_2_F033
# Ses01F_script02_2_F034
# Ses01F_script02_2_F035
# Ses01F_script02_2_F036
# Ses01F_script02_2_F037
# Ses01F_script02_2_F038
# Ses01F_script02_2_F039
# Ses01F_script02_2_F040
# Ses01F_script02_2_F041
# Ses01F_script02_2_F042
# Ses01F_script02_2_F043
# Ses01F_script02_2_F044
# Ses01F_script02_2_F045
# Ses01F_script02_2_F046
# Ses01F_script02_2_F047
# Ses01F_script02_2_M000
# Ses01F_script02_2_M001
# Ses01F_script02_2_M002
# Ses01F_script02_2_M003
# Ses01F_script02_2_M004
# Ses01F_script02_2_M005
# Ses01F_script02_2_M006
# Ses01F_script02_2_M007
# Ses01F_script02_2_M008
# Ses01F_script02_2_M009
# Ses01F_script02_2_M010
# Ses01F_script02_2_M011
# Ses01F_script02_2_M012
# Ses01F_script02_2_M013
# Ses01F_script02_2_M014
# Ses01F_script02_2_M015
# Ses01F_script02_2_M016
# Ses01F_script02_2_M017
# Ses01F_script02_2_M018
# Ses01F_script02_2_M019
# Ses01F_script02_2_M020
# Ses01F_script02_2_M021
# Ses01F_script02_2_M022
# Ses01F_script02_2_M023
# Ses01F_script02_2_M024
# Ses01F_script02_2_M025
# Ses01F_script02_2_M026
# Ses01F_script02_2_M027
# Ses01F_script02_2_M028
# Ses01F_script02_2_M029
# Ses01F_script02_2_M030
# Ses01F_script02_2_M031
# Ses01F_script02_2_M032
# Ses01F_script02_2_M033
# Ses01F_script02_2_M034
# Ses01F_script02_2_M035
# Ses01F_script02_2_M036
# Ses01F_script02_2_M037
# Ses01F_script02_2_M038
# Ses01F_script02_2_M039
# Ses01F_script02_2_M040
# Ses01F_script02_2_M041
# Ses01F_script02_2_M042
# Ses01F_script02_2_M043
# Ses01F_script02_2_M044
# Ses01F_script02_2_M045
# Ses01F_script02_2_M046
# Ses01F_script02_2_M047
# Ses01F_script02_2_M048
# Ses01F_script02_2_M049
# #Ses01F_script03_1: opening Ses01F_script03_1_e1_cat.txt
# #Ses01F_script03_1: opening Ses01F_script03_1_e2_cat.txt
# #Ses01F_script03_1: opening Ses01F_script03_1_e6_cat.txt
# Ses01F_script03_1_F000
# Ses01F_script03_1_F001
# Ses01F_script03_1_F002
# Ses01F_script03_1_F003
# Ses01F_script03_1_F004
# Ses01F_script03_1_F005
# Ses01F_script03_1_F006
# Ses01F_script03_1_F007
# Ses01F_script03_1_F008
# Ses01F_script03_1_F009
# Ses01F_script03_1_F010
# Ses01F_script03_1_F011
# Ses01F_script03_1_F012
# Ses01F_script03_1_F013
# Ses01F_script03_1_F014
# Ses01F_script03_1_F015
# Ses01F_script03_1_F016
# Ses01F_script03_1_F017
# Ses01F_script03_1_F018
# Ses01F_script03_1_F019
# Ses01F_script03_1_F020
# Ses01F_script03_1_F021
# Ses01F_script03_1_F022
# Ses01F_script03_1_F023
# Ses01F_script03_1_F024
# Ses01F_script03_1_F025
# Ses01F_script03_1_F026
# Ses01F_script03_1_F027
# Ses01F_script03_1_F028
# Ses01F_script03_1_F029
# Ses01F_script03_1_F030
# Ses01F_script03_1_F031
# Ses01F_script03_1_M000
# Ses01F_script03_1_M001
# Ses01F_script03_1_M002
# Ses01F_script03_1_M003
# Ses01F_script03_1_M004
# Ses01F_script03_1_M005
# Ses01F_script03_1_M006
# Ses01F_script03_1_M007
# Ses01F_script03_1_M008
# Ses01F_script03_1_M009
# Ses01F_script03_1_M010
# Ses01F_script03_1_M011
# Ses01F_script03_1_M012
# Ses01F_script03_1_M013
# Ses01F_script03_1_M014
# Ses01F_script03_1_M015
# Ses01F_script03_1_M016
# Ses01F_script03_1_M017
# Ses01F_script03_1_M018
# Ses01F_script03_1_M019
# Ses01F_script03_1_M020
# Ses01F_script03_1_M021
# Ses01F_script03_1_M022
# Ses01F_script03_1_M023
# Ses01F_script03_1_M024
# Ses01F_script03_1_M025
# Ses01F_script03_1_M026
# Ses01F_script03_1_M027
# Ses01F_script03_1_M028
# Ses01F_script03_1_M029
# Ses01F_script03_1_M030
# Ses01F_script03_1_M031
# Ses01F_script03_1_M032
# Ses01F_script03_1_M033
# Ses01F_script03_1_M034
# Ses01F_script03_1_M035
# Ses01F_script03_1_M036
# Ses01F_script03_1_M037
# Ses01F_script03_1_M038
# #Ses01F_script03_2: opening Ses01F_script03_2_e1_cat.txt
# #Ses01F_script03_2: opening Ses01F_script03_2_e2_cat.txt
# #Ses01F_script03_2: opening Ses01F_script03_2_e4_cat.txt
# Ses01F_script03_2_F000
# Ses01F_script03_2_F001
# Ses01F_script03_2_F002
# Ses01F_script03_2_F003
# Ses01F_script03_2_F004
# Ses01F_script03_2_F005
# Ses01F_script03_2_F006
# Ses01F_script03_2_F007
# Ses01F_script03_2_F008
# Ses01F_script03_2_F009
# Ses01F_script03_2_F010
# Ses01F_script03_2_F011
# Ses01F_script03_2_F012
# Ses01F_script03_2_F013
# Ses01F_script03_2_F014
# Ses01F_script03_2_F015
# Ses01F_script03_2_F016
# Ses01F_script03_2_F017
# Ses01F_script03_2_F018
# Ses01F_script03_2_F019
# Ses01F_script03_2_F020
# Ses01F_script03_2_F021
# Ses01F_script03_2_F022
# Ses01F_script03_2_F023
# Ses01F_script03_2_F024
# Ses01F_script03_2_F025
# Ses01F_script03_2_F026
# Ses01F_script03_2_F027
# Ses01F_script03_2_F028
# Ses01F_script03_2_F029
# Ses01F_script03_2_F030
# Ses01F_script03_2_F031
# Ses01F_script03_2_F032
# Ses01F_script03_2_F033
# Ses01F_script03_2_F034
# Ses01F_script03_2_F035
# Ses01F_script03_2_F036
# Ses01F_script03_2_F037
# Ses01F_script03_2_F038
# Ses01F_script03_2_F039
# Ses01F_script03_2_F040
# Ses01F_script03_2_M000
# Ses01F_script03_2_M001
# Ses01F_script03_2_M002
# Ses01F_script03_2_M003
# Ses01F_script03_2_M004
# Ses01F_script03_2_M005
# Ses01F_script03_2_M006
# Ses01F_script03_2_M007
# Ses01F_script03_2_M008
# Ses01F_script03_2_M009
# Ses01F_script03_2_M010
# Ses01F_script03_2_M011
# Ses01F_script03_2_M012
# Ses01F_script03_2_M013
# Ses01F_script03_2_M014
# Ses01F_script03_2_M015
# Ses01F_script03_2_M016
# Ses01F_script03_2_M017
# Ses01F_script03_2_M018
# Ses01F_script03_2_M019
# Ses01F_script03_2_M020
# Ses01F_script03_2_M021
# Ses01F_script03_2_M022
# Ses01F_script03_2_M023
# Ses01F_script03_2_M024
# Ses01F_script03_2_M025
# Ses01F_script03_2_M026
# Ses01F_script03_2_M027
# Ses01F_script03_2_M028
# Ses01F_script03_2_M029
# Ses01F_script03_2_M030
# Ses01F_script03_2_M031
# Ses01F_script03_2_M032
# Ses01F_script03_2_M033
# Ses01F_script03_2_M034
# Ses01F_script03_2_M035
# Ses01F_script03_2_M036
# Ses01F_script03_2_M037
# Ses01F_script03_2_M038
# Ses01F_script03_2_M039
# Ses01F_script03_2_M040
# #Ses01M_impro01: opening Ses01M_impro01_e1_cat.txt
# Ses02F_impro01_F001
# Ses02F_impro01_F002
# Ses02F_impro01_F003
# Ses02F_impro01_F004
# Ses02F_impro01_F005
# Ses02F_impro01_F006
# Ses02F_impro01_F007
# Ses02F_impro01_F008
# Ses02F_impro01_F009
# Ses02F_impro01_F010
# Ses02F_impro01_F011
# Ses02F_impro01_F012
# Ses02F_impro01_F013
# Ses02F_impro01_F014
# Ses02F_impro01_F015
# Ses02F_impro01_F016
# Ses02F_impro01_F017
# Ses02F_impro01_F018
# Ses02F_impro01_F019
# Ses02F_impro01_F020
# Ses02F_impro01_F021
# Ses02F_impro01_F022
# Ses02F_impro01_F023
# Ses02F_impro01_M000
# Ses02F_impro01_M001
# Ses02F_impro01_M002
# Ses02F_impro01_M003
# Ses02F_impro01_M004
# Ses02F_impro01_M005
# Ses02F_impro01_M006
# Ses02F_impro01_M007
# Ses02F_impro01_M008
# Ses02F_impro01_M009
# Ses02F_impro01_M010
# Ses02F_impro01_M011
# Ses02F_impro01_M012
# Ses02F_impro01_M013
# Ses02F_impro01_M014
# Ses02F_impro01_M015
# Ses02F_impro01_M016
# Ses02F_impro01_M017
# Ses02F_impro01_M018
# Ses02F_impro01_M019
# Ses02F_impro01_M020
# Ses02F_impro01_M021
# Ses02F_impro01_M022
# Ses02F_impro01_M023
# Ses02F_impro01_M024
# #Ses02F_impro02: opening Ses02F_impro02_e1_cat.txt
# #Ses02F_impro02: opening Ses02F_impro02_e2_cat.txt
# #Ses02F_impro02: opening Ses02F_impro02_e6_cat.txt
# Ses02F_impro02_F000
# Ses02F_impro02_F001
# Ses02F_impro02_F002
# Ses02F_impro02_F003
# Ses02F_impro02_F004
# Ses02F_impro02_F005
# Ses02F_impro02_F006
# Ses02F_impro02_F007
# Ses02F_impro02_F008
# Ses02F_impro02_F009
# Ses02F_impro02_F010
# Ses02F_impro02_F011
# Ses02F_impro02_F012
# Ses02F_impro02_F013
# Ses02F_impro02_M000
# Ses02F_impro02_M001
# Ses02F_impro02_M002
# Ses02F_impro02_M003
# Ses02F_impro02_M004
# Ses02F_impro02_M005
# Ses02F_impro02_M006
# Ses02F_impro02_M007
# Ses02F_impro02_M008
# Ses02F_impro02_M009
# Ses02F_impro02_M010
# Ses02F_impro02_M011
# Ses02F_impro02_M012
# #Ses02F_impro03: opening Ses02F_impro03_e1_cat.txt
# #Ses02F_impro03: opening Ses02F_impro03_e2_cat.txt
# #Ses02F_impro03: opening Ses02F_impro03_e4_cat.txt
# Ses02F_impro03_F000
# Ses02F_impro03_F001
# Ses02F_impro03_F002
# Ses02F_impro03_F003
# Ses02F_impro03_F004
# Ses02F_impro03_F005
# Ses02F_impro03_F006
# Ses02F_impro03_F007
# Ses02F_impro03_F008
# Ses02F_impro03_F009
# Ses02F_impro03_F010
# Ses02F_impro03_F011
# Ses02F_impro03_F012
# Ses02F_impro03_F013
# Ses02F_impro03_F014
# Ses02F_impro03_F015
# Ses02F_impro03_F016
# Ses02F_impro03_F017
# Ses02F_impro03_F018
# Ses02F_impro03_F019
# Ses02F_impro03_F020
# Ses02F_impro03_F021
# Ses02F_impro03_F022
# Ses02F_impro03_F023
# Ses02F_impro03_F024
# Ses02F_impro03_F025
# Ses02F_impro03_F026
# Ses02F_impro03_F027
# Ses02F_impro03_F028
# Ses02F_impro03_F029
# Ses02F_impro03_F030
# Ses02F_impro03_M000
# Ses02F_impro03_M001
# Ses02F_impro03_M002
# Ses02F_impro03_M003
# Ses02F_impro03_M004
# Ses02F_impro03_M005
# Ses02F_impro03_M006
# Ses02F_impro03_M007
# Ses02F_impro03_M008
# Ses02F_impro03_M009
# Ses02F_impro03_M010
# Ses02F_impro03_M011
# Ses02F_impro03_M012
# Ses02F_impro03_M013
# Ses02F_impro03_M014
# Ses02F_impro03_M015
# Ses02F_impro03_M016
# Ses02F_impro03_M017
# Ses02F_impro03_M018
# Ses02F_impro03_M019
# Ses02F_impro03_M020
# Ses02F_impro03_M021
# Ses02F_impro03_M022
# Ses02F_impro03_M023
# Ses02F_impro03_M024
# Ses02F_impro03_M025
# Ses02F_impro03_M026
# #Ses02F_impro04: opening Ses02F_impro04_e1_cat.txt
# #Ses02F_impro04: opening Ses02F_impro04_e2_cat.txt
# #Ses02F_impro04: opening Ses02F_impro04_e4_cat.txt
# Ses02F_impro04_F000
# Ses02F_impro04_F001
# Ses02F_impro04_F002
# Ses02F_impro04_F003
# Ses02F_impro04_F004
# Ses02F_impro04_F005
# Ses02F_impro04_F006
# Ses02F_impro04_F007
# Ses02F_impro04_F008
# Ses02F_impro04_F009
# Ses02F_impro04_F010
# Ses02F_impro04_F011
# Ses02F_impro04_F012
# Ses02F_impro04_F013
# Ses02F_impro04_F014
# Ses02F_impro04_F015
# Ses02F_impro04_F016
# Ses02F_impro04_F017
# Ses02F_impro04_M000
# Ses02F_impro04_M001
# Ses02F_impro04_M002
# Ses02F_impro04_M003
# Ses02F_impro04_M004
# Ses02F_impro04_M005
# Ses02F_impro04_M006
# Ses02F_impro04_M007
# Ses02F_impro04_M008
# Ses02F_impro04_M009
# Ses02F_impro04_M010
# Ses02F_impro04_M011
# ...
# Ses05M_impro07_M040
# Ses05M_impro07_M041
# Ses05M_impro07_M042
# Ses05M_impro07_M043
# Ses05M_impro07_M044
# Ses05M_impro07_M045
# Ses05M_impro07_M046
# Ses05M_impro07_M047
# #Ses05M_impro08: opening Ses05M_impro08_e1_cat.txt
# #Ses05M_impro08: opening Ses05M_impro08_e2_cat.txt
# #Ses05M_impro08: opening Ses05M_impro08_e4_cat.txt
# Ses05M_impro08_F000
# Ses05M_impro08_F001
# Ses05M_impro08_F002
# Ses05M_impro08_F003
# Ses05M_impro08_F004
# Ses05M_impro08_F005
# Ses05M_impro08_F006
# Ses05M_impro08_F007
# Ses05M_impro08_F008
# Ses05M_impro08_F009
# Ses05M_impro08_F010
# Ses05M_impro08_F011
# Ses05M_impro08_F012
# Ses05M_impro08_F013
# Ses05M_impro08_F014
# Ses05M_impro08_F015
# Ses05M_impro08_F016
# Ses05M_impro08_F017
# Ses05M_impro08_F018
# Ses05M_impro08_F019
# Ses05M_impro08_F020
# Ses05M_impro08_F021
# Ses05M_impro08_F022
# Ses05M_impro08_F023
# Ses05M_impro08_F024
# Ses05M_impro08_F025
# Ses05M_impro08_F026
# Ses05M_impro08_F027
# Ses05M_impro08_F028
# Ses05M_impro08_M000
# Ses05M_impro08_M001
# Ses05M_impro08_M002
# Ses05M_impro08_M003
# Ses05M_impro08_M004
# Ses05M_impro08_M005
# Ses05M_impro08_M006
# Ses05M_impro08_M007
# Ses05M_impro08_M008
# Ses05M_impro08_M009
# Ses05M_impro08_M010
# Ses05M_impro08_M011
# Ses05M_impro08_M012
# Ses05M_impro08_M013
# Ses05M_impro08_M014
# Ses05M_impro08_M015
# Ses05M_impro08_M016
# Ses05M_impro08_M017
# Ses05M_impro08_M018
# Ses05M_impro08_M019
# Ses05M_impro08_M020
# Ses05M_impro08_M021
# Ses05M_impro08_M022
# Ses05M_impro08_M023
# Ses05M_impro08_M024
# Ses05M_impro08_M025
# Ses05M_impro08_M026
# Ses05M_impro08_M027
# Ses05M_impro08_M028
# #Ses05M_script01_1: opening Ses05M_script01_1_e1_cat.txt
# #Ses05M_script01_1: opening Ses05M_script01_1_e2_cat.txt
# #Ses05M_script01_1: opening Ses05M_script01_1_e4_cat.txt
# #Ses05M_script01_1: opening Ses05M_script01_1b_e1_cat.txt
# #Ses05M_script01_1: opening Ses05M_script01_1b_e2_cat.txt
# #Ses05M_script01_1: opening Ses05M_script01_1b_e4_cat.txt
# Ses05M_script01_1_F000
# Ses05M_script01_1_F001
# Ses05M_script01_1_F002
# Ses05M_script01_1_F003
# Ses05M_script01_1_F004
# Ses05M_script01_1_F005
# Ses05M_script01_1_F006
# Ses05M_script01_1_F007
# Ses05M_script01_1_F008
# Ses05M_script01_1_F009
# Ses05M_script01_1_F010
# Ses05M_script01_1_F011
# Ses05M_script01_1_F012
# Ses05M_script01_1_F013
# Ses05M_script01_1_F014
# Ses05M_script01_1_F015
# Ses05M_script01_1_F016
# Ses05M_script01_1_F017
# Ses05M_script01_1_F018
# Ses05M_script01_1_F019
# Ses05M_script01_1_F020
# Ses05M_script01_1_F021
# Ses05M_script01_1_F022
# Ses05M_script01_1_F023
# Ses05M_script01_1_F024
# Ses05M_script01_1_F025
# Ses05M_script01_1_F026
# Ses05M_script01_1_F027
# Ses05M_script01_1_F028
# Ses05M_script01_1_F029
# Ses05M_script01_1_F030
# Ses05M_script01_1_F031
# Ses05M_script01_1_F032
# Ses05M_script01_1_F033
# Ses05M_script01_1_F034
# Ses05M_script01_1_F035
# Ses05M_script01_1_F036
# Ses05M_script01_1_F037
# Ses05M_script01_1_F038
# Ses05M_script01_1_M000
# Ses05M_script01_1_M001
# Ses05M_script01_1_M002
# Ses05M_script01_1_M003
# Ses05M_script01_1_M004
# Ses05M_script01_1_M005
# Ses05M_script01_1_M006
# Ses05M_script01_1_M007
# Ses05M_script01_1_M008
# Ses05M_script01_1_M009
# Ses05M_script01_1_M010
# Ses05M_script01_1_M011
# Ses05M_script01_1_M012
# Ses05M_script01_1_M013
# Ses05M_script01_1_M014
# Ses05M_script01_1_M015
# Ses05M_script01_1_M016
# Ses05M_script01_1_M017
# Ses05M_script01_1_M018
# Ses05M_script01_1_M019
# Ses05M_script01_1_M020
# Ses05M_script01_1_M021
# Ses05M_script01_1_M022
# Ses05M_script01_1_M023
# Ses05M_script01_1_M024
# Ses05M_script01_1_M025
# Ses05M_script01_1_M026
# Ses05M_script01_1_M027
# Ses05M_script01_1_M028
# Ses05M_script01_1_M029
# Ses05M_script01_1_M030
# Ses05M_script01_1_M031
# Ses05M_script01_1_M032
# Ses05M_script01_1_M033
# Ses05M_script01_1_M034
# Ses05M_script01_1_M035
# Ses05M_script01_1_M036
# Ses05M_script01_1_M037
# Ses05M_script01_1_M038
# Ses05M_script01_1_M039
# Ses05M_script01_1_M040
# #Ses05M_script01_1b: opening Ses05M_script01_1b_e1_cat.txt
# #Ses05M_script01_1b: opening Ses05M_script01_1b_e2_cat.txt
# #Ses05M_script01_1b: opening Ses05M_script01_1b_e4_cat.txt
# Ses05M_script01_1b_F000
# Ses05M_script01_1b_F001
# Ses05M_script01_1b_F002
# Ses05M_script01_1b_F003
# Ses05M_script01_1b_F004
# Ses05M_script01_1b_F005
# Ses05M_script01_1b_F006
# Ses05M_script01_1b_F007
# Ses05M_script01_1b_F008
# Ses05M_script01_1b_F009
# Ses05M_script01_1b_F010
# Ses05M_script01_1b_F011
# Ses05M_script01_1b_F012
# Ses05M_script01_1b_F013
# Ses05M_script01_1b_F014
# Ses05M_script01_1b_F015
# Ses05M_script01_1b_F016
# Ses05M_script01_1b_F017
# Ses05M_script01_1b_F018
# Ses05M_script01_1b_F019
# Ses05M_script01_1b_F020
# Ses05M_script01_1b_F021
# Ses05M_script01_1b_F022
# Ses05M_script01_1b_F023
# Ses05M_script01_1b_F024
# Ses05M_script01_1b_F025
# Ses05M_script01_1b_F026
# Ses05M_script01_1b_F027
# Ses05M_script01_1b_F028
# Ses05M_script01_1b_F029
# Ses05M_script01_1b_F030
# Ses05M_script01_1b_F031
# Ses05M_script01_1b_F032
# Ses05M_script01_1b_F033
# Ses05M_script01_1b_F034
# Ses05M_script01_1b_F035
# Ses05M_script01_1b_F036
# Ses05M_script01_1b_F037
# Ses05M_script01_1b_F038
# Ses05M_script01_1b_M000
# Ses05M_script01_1b_M001
# Ses05M_script01_1b_M002
# Ses05M_script01_1b_M003
# Ses05M_script01_1b_M004
# Ses05M_script01_1b_M005
# Ses05M_script01_1b_M006
# Ses05M_script01_1b_M007
# Ses05M_script01_1b_M008
# Ses05M_script01_1b_M009
# Ses05M_script01_1b_M010
# Ses05M_script01_1b_M011
# Ses05M_script01_1b_M012
# Ses05M_script01_1b_M013
# Ses05M_script01_1b_M014
# Ses05M_script01_1b_M015
# Ses05M_script01_1b_M016
# Ses05M_script01_1b_M017
# Ses05M_script01_1b_M018
# Ses05M_script01_1b_M019
# Ses05M_script01_1b_M020
# Ses05M_script01_1b_M021
# Ses05M_script01_1b_M022
# Ses05M_script01_1b_M023
# Ses05M_script01_1b_M024
# Ses05M_script01_1b_M025
# Ses05M_script01_1b_M026
# Ses05M_script01_1b_M027
# Ses05M_script01_1b_M028
# Ses05M_script01_1b_M029
# Ses05M_script01_1b_M030
# Ses05M_script01_1b_M031
# Ses05M_script01_1b_M032
# Ses05M_script01_1b_M033
# Ses05M_script01_1b_M034
# Ses05M_script01_1b_M035
# Ses05M_script01_1b_M036
# Ses05M_script01_1b_M037
# Ses05M_script01_1b_M038
# Ses05M_script01_1b_M039
# Ses05M_script01_1b_M040
# Ses05M_script01_1b_M041
# #Ses05M_script01_2: opening Ses05M_script01_2_e1_cat.txt
# #Ses05M_script01_2: opening Ses05M_script01_2_e2_cat.txt
# #Ses05M_script01_2: opening Ses05M_script01_2_e4_cat.txt
# Ses05M_script01_2_F000
# Ses05M_script01_2_F001
# Ses05M_script01_2_F002
# Ses05M_script01_2_F003
# Ses05M_script01_2_F004
# Ses05M_script01_2_F005
# Ses05M_script01_2_F006
# Ses05M_script01_2_F007
# Ses05M_script01_2_F008
# Ses05M_script01_2_F009
# Ses05M_script01_2_F010
# Ses05M_script01_2_F011
# Ses05M_script01_2_F012
# Ses05M_script01_2_F013
# Ses05M_script01_2_F014
# Ses05M_script01_2_F015
# Ses05M_script01_2_F016
# Ses05M_script01_2_F017
# Ses05M_script01_2_M000
# Ses05M_script01_2_M001
# Ses05M_script01_2_M002
# Ses05M_script01_2_M003
# Ses05M_script01_2_M004
# Ses05M_script01_2_M005
# Ses05M_script01_2_M006
# Ses05M_script01_2_M007
# Ses05M_script01_2_M008
# Ses05M_script01_2_M009
# Ses05M_script01_2_M010
# Ses05M_script01_2_M011
# Ses05M_script01_2_M012
# Ses05M_script01_2_M013
# Ses05M_script01_2_M014
# Ses05M_script01_2_M015
# Ses05M_script01_2_M016
# #Ses05M_script01_3: opening Ses05M_script01_3_e1_cat.txt
# #Ses05M_script01_3: opening Ses05M_script01_3_e2_cat.txt
# #Ses05M_script01_3: opening Ses05M_script01_3_e4_cat.txt
# Ses05M_script01_3_F000
# Ses05M_script01_3_F001
# Ses05M_script01_3_F002
# Ses05M_script01_3_F003
# Ses05M_script01_3_F004
# Ses05M_script01_3_F005
# Ses05M_script01_3_F006
# Ses05M_script01_3_F007
# Ses05M_script01_3_F008
# Ses05M_script01_3_F009
# Ses05M_script01_3_F010
# Ses05M_script01_3_F011
# Ses05M_script01_3_F012
# Ses05M_script01_3_F013
# Ses05M_script01_3_F014
# Ses05M_script01_3_F015
# Ses05M_script01_3_F016
# Ses05M_script01_3_F017
# Ses05M_script01_3_F018
# Ses05M_script01_3_F019
# Ses05M_script01_3_F020
# Ses05M_script01_3_F021
# Ses05M_script01_3_F022
# Ses05M_script01_3_F023
# Ses05M_script01_3_F024
# Ses05M_script01_3_F025
# Ses05M_script01_3_F026
# Ses05M_script01_3_F027
# Ses05M_script01_3_M000
# Ses05M_script01_3_M001
# Ses05M_script01_3_M002
# Ses05M_script01_3_M003
# Ses05M_script01_3_M004
# Ses05M_script01_3_M005
# Ses05M_script01_3_M006
# Ses05M_script01_3_M007
# Ses05M_script01_3_M008
# Ses05M_script01_3_M009
# Ses05M_script01_3_M010
# Ses05M_script01_3_M011
# Ses05M_script01_3_M012
# Ses05M_script01_3_M013
# Ses05M_script01_3_M014
# Ses05M_script01_3_M015
# Ses05M_script01_3_M016
# Ses05M_script01_3_M017
# Ses05M_script01_3_M018
# Ses05M_script01_3_M019
# Ses05M_script01_3_M020
# Ses05M_script01_3_M021
# Ses05M_script01_3_M022
# Ses05M_script01_3_M023
# Ses05M_script01_3_M024
# Ses05M_script01_3_M025
# Ses05M_script01_3_M026
# Ses05M_script01_3_M027
# Ses05M_script01_3_M028
# Ses05M_script01_3_M029
# Ses05M_script01_3_M030
# Ses05M_script01_3_M031
# Ses05M_script01_3_M032
# Ses05M_script01_3_M033
# Ses05M_script01_3_M034
# Ses05M_script01_3_M035
# Ses05M_script01_3_M036
# Ses05M_script01_3_M037
# Ses05M_script01_3_M038
# Ses05M_script01_3_M039
# Ses05M_script01_3_M040
# Ses05M_script01_3_M041
# Ses05M_script01_3_M042
# #Ses05M_script02_1: opening Ses05M_script02_1_e1_cat.txt
# #Ses05M_script02_1: opening Ses05M_script02_1_e2_cat.txt
# #Ses05M_script02_1: opening Ses05M_script02_1_e4_cat.txt
# Ses05M_script02_1_F000
# Ses05M_script02_1_F001
# Ses05M_script02_1_F002
# Ses05M_script02_1_F003
# Ses05M_script02_1_F004
# Ses05M_script02_1_F005
# Ses05M_script02_1_F006
# Ses05M_script02_1_F007
# Ses05M_script02_1_F008
# Ses05M_script02_1_F009
# Ses05M_script02_1_F010
# Ses05M_script02_1_F011
# Ses05M_script02_1_F012
# Ses05M_script02_1_F013
# Ses05M_script02_1_F014
# Ses05M_script02_1_F015
# Ses05M_script02_1_F016
# Ses05M_script02_1_F017
# Ses05M_script02_1_F018
# Ses05M_script02_1_F019
# Ses05M_script02_1_F020
# Ses05M_script02_1_M000
# Ses05M_script02_1_M001
# Ses05M_script02_1_M002
# Ses05M_script02_1_M003
# Ses05M_script02_1_M004
# Ses05M_script02_1_M005
# Ses05M_script02_1_M006
# Ses05M_script02_1_M007
# Ses05M_script02_1_M008
# Ses05M_script02_1_M009
# Ses05M_script02_1_M010
# Ses05M_script02_1_M011
# Ses05M_script02_1_M012
# Ses05M_script02_1_M013
# Ses05M_script02_1_M014
# Ses05M_script02_1_M015
# Ses05M_script02_1_M016
# Ses05M_script02_1_M017
# Ses05M_script02_1_M018
# Ses05M_script02_1_M019
# Ses05M_script02_1_M020
# Ses05M_script02_1_M021
# Ses05M_script02_1_M022
# Ses05M_script02_1_M023
# Ses05M_script02_1_M024
# Ses05M_script02_1_M025
# Ses05M_script02_1_M026
# Ses05M_script02_1_M027
# Ses05M_script02_1_M028
# Ses05M_script02_1_M029
# Ses05M_script02_1_M030
# Ses05M_script02_1_M031
# Ses05M_script02_1_M032
# Ses05M_script02_1_M033
# #Ses05M_script02_2: opening Ses05M_script02_2_e1_cat.txt
# #Ses05M_script02_2: opening Ses05M_script02_2_e2_cat.txt
# #Ses05M_script02_2: opening Ses05M_script02_2_e4_cat.txt
# Ses05M_script02_2_F000
# Ses05M_script02_2_F001
# Ses05M_script02_2_F002
# Ses05M_script02_2_F003
# Ses05M_script02_2_F004
# Ses05M_script02_2_F005
# Ses05M_script02_2_F006
# Ses05M_script02_2_F007
# Ses05M_script02_2_F008
# Ses05M_script02_2_F009
# Ses05M_script02_2_F010
# Ses05M_script02_2_F011
# Ses05M_script02_2_F012
# Ses05M_script02_2_F013
# Ses05M_script02_2_F014
# Ses05M_script02_2_F015
# Ses05M_script02_2_F016
# Ses05M_script02_2_F017
# Ses05M_script02_2_F018
# Ses05M_script02_2_F019
# Ses05M_script02_2_F020
# Ses05M_script02_2_F021
# Ses05M_script02_2_F022
# Ses05M_script02_2_F023
# Ses05M_script02_2_F024
# Ses05M_script02_2_F025
# Ses05M_script02_2_F026
# Ses05M_script02_2_F027
# Ses05M_script02_2_F028
# Ses05M_script02_2_F029
# Ses05M_script02_2_F030
# Ses05M_script02_2_F031
# Ses05M_script02_2_F032
# Ses05M_script02_2_F033
# Ses05M_script02_2_F034
# Ses05M_script02_2_F035
# Ses05M_script02_2_F036
# Ses05M_script02_2_F037
# Ses05M_script02_2_F038
# Ses05M_script02_2_M000
# Ses05M_script02_2_M001
# Ses05M_script02_2_M002
# Ses05M_script02_2_M003
# Ses05M_script02_2_M004
# Ses05M_script02_2_M005
# Ses05M_script02_2_M006
# Ses05M_script02_2_M007
# Ses05M_script02_2_M008
# Ses05M_script02_2_M009
# Ses05M_script02_2_M010
# Ses05M_script02_2_M011
# Ses05M_script02_2_M012
# Ses05M_script02_2_M013
# Ses05M_script02_2_M014
# Ses05M_script02_2_M015
# Ses05M_script02_2_M016
# Ses05M_script02_2_M017
# Ses05M_script02_2_M018
# Ses05M_script02_2_M019
# Ses05M_script02_2_M020
# Ses05M_script02_2_M021
# Ses05M_script02_2_M022
# Ses05M_script02_2_M023
# Ses05M_script02_2_M024
# Ses05M_script02_2_M025
# Ses05M_script02_2_M026
# Ses05M_script02_2_M027
# Ses05M_script02_2_M028
# Ses05M_script02_2_M029
# Ses05M_script02_2_M030
# Ses05M_script02_2_M031
# Ses05M_script02_2_M032
# Ses05M_script02_2_M033
# Ses05M_script02_2_M034
# Ses05M_script02_2_M035
# Ses05M_script02_2_M036
# Ses05M_script02_2_M037
# Ses05M_script02_2_M038
# Ses05M_script02_2_M039
# Ses05M_script02_2_M040
# #Ses05M_script03_1: opening Ses05M_script03_1_e1_cat.txt
# #Ses05M_script03_1: opening Ses05M_script03_1_e2_cat.txt
# #Ses05M_script03_1: opening Ses05M_script03_1_e4_cat.txt
# Ses05M_script03_1_F000
# Ses05M_script03_1_F001
# Ses05M_script03_1_F002
# Ses05M_script03_1_F003
# Ses05M_script03_1_F004
# Ses05M_script03_1_F005
# Ses05M_script03_1_F006
# Ses05M_script03_1_F007
# Ses05M_script03_1_F008
# Ses05M_script03_1_F009
# Ses05M_script03_1_F010
# Ses05M_script03_1_F011
# Ses05M_script03_1_F012
# Ses05M_script03_1_F013
# Ses05M_script03_1_F014
# Ses05M_script03_1_F015
# Ses05M_script03_1_F016
# Ses05M_script03_1_F017
# Ses05M_script03_1_F018
# Ses05M_script03_1_F019
# Ses05M_script03_1_F020
# Ses05M_script03_1_F021
# Ses05M_script03_1_F022
# Ses05M_script03_1_F023
# Ses05M_script03_1_F024
# Ses05M_script03_1_F025
# Ses05M_script03_1_F026
# Ses05M_script03_1_F027
# Ses05M_script03_1_F028
# Ses05M_script03_1_F029
# Ses05M_script03_1_F030
# Ses05M_script03_1_F031
# Ses05M_script03_1_M000
# Ses05M_script03_1_M001
# Ses05M_script03_1_M002
# Ses05M_script03_1_M003
# Ses05M_script03_1_M004
# Ses05M_script03_1_M005
# Ses05M_script03_1_M006
# Ses05M_script03_1_M007
# Ses05M_script03_1_M008
# Ses05M_script03_1_M009
# Ses05M_script03_1_M010
# Ses05M_script03_1_M011
# Ses05M_script03_1_M012
# Ses05M_script03_1_M013
# Ses05M_script03_1_M014
# Ses05M_script03_1_M015
# Ses05M_script03_1_M016
# Ses05M_script03_1_M017
# Ses05M_script03_1_M018
# Ses05M_script03_1_M019
# Ses05M_script03_1_M020
# Ses05M_script03_1_M021
# Ses05M_script03_1_M022
# Ses05M_script03_1_M023
# Ses05M_script03_1_M024
# Ses05M_script03_1_M025
# Ses05M_script03_1_M026
# Ses05M_script03_1_M027
# Ses05M_script03_1_M028
# Ses05M_script03_1_M029
# Ses05M_script03_1_M030
# Ses05M_script03_1_M031
# Ses05M_script03_1_M032
# Ses05M_script03_1_M033
# Ses05M_script03_1_M034
# #Ses05M_script03_2: opening Ses05M_script03_2_e1_cat.txt
# #Ses05M_script03_2: opening Ses05M_script03_2_e2_cat.txt
# #Ses05M_script03_2: opening Ses05M_script03_2_e4_cat.txt
# Ses05M_script03_2_F000
# Ses05M_script03_2_F001
# Ses05M_script03_2_F002
# Ses05M_script03_2_F003
# Ses05M_script03_2_F004
# Ses05M_script03_2_F005
# Ses05M_script03_2_F006
# Ses05M_script03_2_F007
# Ses05M_script03_2_F008
# Ses05M_script03_2_F009
# Ses05M_script03_2_F010
# Ses05M_script03_2_F011
# Ses05M_script03_2_F012
# Ses05M_script03_2_F013
# Ses05M_script03_2_F014
# Ses05M_script03_2_F015
# Ses05M_script03_2_F016
# Ses05M_script03_2_F017
# Ses05M_script03_2_F018
# Ses05M_script03_2_F019
# Ses05M_script03_2_F020
# Ses05M_script03_2_F021
# Ses05M_script03_2_F022
# Ses05M_script03_2_F023
# Ses05M_script03_2_F024
# Ses05M_script03_2_F025
# Ses05M_script03_2_F026
# Ses05M_script03_2_F027
# Ses05M_script03_2_F028
# Ses05M_script03_2_F029
# Ses05M_script03_2_F030
# Ses05M_script03_2_F031
# Ses05M_script03_2_F032
# Ses05M_script03_2_F033
# Ses05M_script03_2_F034
# Ses05M_script03_2_F035
# Ses05M_script03_2_F036
# Ses05M_script03_2_F037
# Ses05M_script03_2_F038
# Ses05M_script03_2_F039
# Ses05M_script03_2_F040
# Ses05M_script03_2_F041
# Ses05M_script03_2_F042
# Ses05M_script03_2_F043
# Ses05M_script03_2_F044
# Ses05M_script03_2_M000
# Ses05M_script03_2_M001
# Ses05M_script03_2_M002
# Ses05M_script03_2_M003
# Ses05M_script03_2_M004
# Ses05M_script03_2_M005
# Ses05M_script03_2_M006
# Ses05M_script03_2_M007
# Ses05M_script03_2_M008
# Ses05M_script03_2_M009
# Ses05M_script03_2_M010
# Ses05M_script03_2_M011
# Ses05M_script03_2_M012
# Ses05M_script03_2_M013
# Ses05M_script03_2_M014
# Ses05M_script03_2_M015
# Ses05M_script03_2_M016
# Ses05M_script03_2_M017
# Ses05M_script03_2_M018
# Ses05M_script03_2_M019
# Ses05M_script03_2_M020
# Ses05M_script03_2_M021
# Ses05M_script03_2_M022
# Ses05M_script03_2_M023
# Ses05M_script03_2_M024
# Ses05M_script03_2_M025
# Ses05M_script03_2_M026
# Ses05M_script03_2_M027
# Ses05M_script03_2_M028
# Ses05M_script03_2_M029
# Ses05M_script03_2_M030
# Ses05M_script03_2_M031
# Ses05M_script03_2_M032
# Ses05M_script03_2_M033
# Ses05M_script03_2_M034
# Ses05M_script03_2_M035
# Ses05M_script03_2_M036
# Ses05M_script03_2_M037
# Ses05M_script03_2_M038
# Ses05M_script03_2_M039
# Ses05M_script03_2_M040
# Ses05M_script03_2_M041
# Ses05M_script03_2_M042
# Ses05M_script03_2_M043
# Ses05M_script03_2_M044
# Ses05M_script03_2_M045

# %% [markdown]
# #### 2: ExcitedをHappinessにマージ
#
# 元論文で，ExicitedとHappinessはvalenceとactivationの値が近しいクラスであるためマージ

# %%
def exc_hap_marge(label):
    label_ = label.copy()
    for i in range(len(label_)):
        if label_[i] == 'Excited':
            label_[i] = 'Happiness'
    return label_

# %%
ex_hp_marged = [exc_hap_marge(l) for l in raw_labels]

# %%
# Neutral state をNeutralに表記変え
for label in ex_hp_marged:
    for i in range(len(label)):
        if label[i] == 'Neutral state':
            label[i] = 'Neutral'

# %% [markdown]
# #### 3: 3評価者間でラベル付が割れているファイルを除く

# %%
def unagreed1(label):
    return len(label) == len(collections.Counter(label))

def strictly_agreed(label):
    return len(collections.Counter(label)) == 1

# %%
agreed1 = [label for label in ex_hp_marged if not unagreed1(label)]
speakers1 = [speakers[i] for i in range(len(speakers)) if not unagreed1(ex_hp_marged[i])]
file_paths_1 = [wav_file_paths[i] for i in range(len(wav_file_paths)) if not unagreed1(ex_hp_marged[i])]
file_names1 = [filenames[i] for i in range(len(filenames)) if not unagreed1(ex_hp_marged[i])]
agreed2 = [label for label in ex_hp_marged if strictly_agreed(label)]
speakers2 = [speakers[i] for i in range(len(speakers)) if not strictly_agreed(ex_hp_marged[i])]
file_paths_2 = [wav_file_paths[i] for i in range(len(wav_file_paths)) if strictly_agreed(ex_hp_marged[i])]
file_names2 = [filenames[i] for i in range(len(filenames)) if not strictly_agreed(ex_hp_marged[i])]

# %% [markdown]
# #### 3: 多数決を取って1つのラベルを決定する

# %%
maj_labels1 = [mode(label) for label in agreed1]
maj_labels2 = [label[0] for label in agreed2]

# %%
df1 = pd.DataFrame(maj_labels1)
df2 = pd.DataFrame(maj_labels2)

# %%
df1[0].value_counts()
# Out:
# Happiness      2448
# Frustration    2044
# Neutral        1708
# Sadness        1070
# Anger          1054
# Surprise         98
# Fear             33
# Other             3
# Disgust           2
# Name: 0, dtype: int64

# %%
df2[0].value_counts()
# Out:
# Happiness      1264
# Frustration     557
# Sadness         424
# Neutral         390
# Anger           330
# Surprise          7
# Fear              4
# Name: 0, dtype: int64

# %% [markdown]
# #### 3: 必要な感情ラベルだけ取ってくる
#
# 今回はNeutral, Anger, Sadness, Happinessの4つだけ使うのでそのように選ぶ．

# %%
labels_necessary = ['Anger', 'Neutral', 'Sadness', 'Happiness']

# %%
def data_selection(file_paths, filenames, speakers, labels, necessary_labels):
    files_selected = []
    filenames_selected = []
    speakers_selected = []
    labels_selected = []
    
    for i in range(len(labels)):
        if labels[i] in labels_necessary:
            files_selected.append(file_paths[i])
            filenames_selected.append(filenames[i])
            speakers_selected.append(speakers[i])
            labels_selected.append(labels[i])
    return files_selected, filenames_selected, speakers_selected, labels_selected

# %%
files_selected1, filenames_selected1, speakers_selected1, labels_selected1 = \
    data_selection(file_paths_1, file_names1, speakers1, maj_labels1, labels_necessary)

# %%
files_selected2, filenames_selected2, speakers_selected2, labels_selected2 = \
    data_selection(file_paths_2, file_names2, speakers2, maj_labels2, labels_necessary)

# %%
df1 = pd.DataFrame(list(zip(filenames_selected1, speakers_selected1, labels_selected1)), columns=['filename', 'speaker_id', 'labels'])

# %%
df2 = pd.DataFrame(list(zip(filenames_selected2, speakers_selected2, labels_selected2)), columns=['filename', 'speaker_id', 'labels'])

# %%
df1['labels'].value_counts()
# Out:
# Happiness    2448
# Neutral      1708
# Sadness      1070
# Anger        1054
# Name: labels, dtype: int64

# %%
df2['labels'].value_counts()
# Out:
# Happiness    1264
# Sadness       424
# Neutral       390
# Anger         330
# Name: labels, dtype: int64

# %%
datas = []
for file in files_selected1:
    x, fs = librosa.load(file, sr=16000)
    datas.append([x, fs])

# %%
class dataset:
    def __init__(self):
        self.datas = datas
        self.speakers = speakers_selected1
        self.speaker_mapping = speaker_mapping
        self.labels = labels_selected1
        self.filenames = filenames_selected1

# %%
dataset = dataset()

# %%
dataset.filenames
# Out:
# ['Ses01F_impro01_F000',
#  'Ses01F_impro01_F001',
#  'Ses01F_impro01_F002',
#  'Ses01F_impro01_F005',
#  'Ses01F_impro01_F012',
#  'Ses01F_impro01_F014',
#  'Ses01F_impro01_M013',
#  'Ses01F_impro02_F000',
#  'Ses01F_impro02_F001',
#  'Ses01F_impro02_F002',
#  'Ses01F_impro02_F003',
#  'Ses01F_impro02_F004',
#  'Ses01F_impro02_F005',
#  'Ses01F_impro02_F006',
#  'Ses01F_impro02_F010',
#  'Ses01F_impro02_F012',
#  'Ses01F_impro02_F013',
#  'Ses01F_impro02_F014',
#  'Ses01F_impro02_F015',
#  'Ses01F_impro02_F016',
#  'Ses01F_impro02_F017',
#  'Ses01F_impro02_F018',
#  'Ses01F_impro02_F019',
#  'Ses01F_impro02_F020',
#  'Ses01F_impro02_M009',
#  'Ses01F_impro02_M010',
#  'Ses01F_impro02_M011',
#  'Ses01F_impro06_M015',
#  'Ses01F_impro06_M016',
#  'Ses01F_impro07_F000',
#  'Ses01F_impro07_F001',
#  'Ses01F_impro07_F002',
#  'Ses01F_impro07_F003',
#  'Ses01F_impro07_F004',
#  'Ses01F_impro07_F005',
#  'Ses01F_impro07_F006',
#  'Ses01F_impro07_F007',
#  'Ses01F_impro07_F008',
#  'Ses01F_impro07_F009',
#  'Ses01F_impro07_F010',
#  'Ses01F_impro07_F011',
#  'Ses01F_impro07_F012',
#  'Ses01F_impro07_F013',
#  'Ses01F_impro07_F014',
#  'Ses01F_impro07_F015',
#  'Ses01F_impro07_F016',
#  'Ses01F_impro07_M000',
#  'Ses01F_impro07_M001',
#  'Ses01F_impro07_M002',
#  'Ses01F_impro07_M003',
#  'Ses01F_impro07_M004',
#  'Ses01F_impro07_M005',
#  'Ses01F_impro07_M006',
#  'Ses01F_impro07_M007',
#  'Ses01F_impro07_M008',
#  'Ses01F_impro07_M009',
#  'Ses01F_impro07_M011',
#  'Ses01F_impro07_M012',
#  'Ses01F_impro07_M013',
#  'Ses01F_impro07_M014',
#  'Ses01F_impro07_M015',
#  'Ses01F_impro07_M016',
#  'Ses01F_impro07_M017',
#  'Ses01F_impro07_M018',
#  'Ses01F_impro07_M019',
#  'Ses01F_script01_1_F005',
#  'Ses01F_script01_1_F015',
#  'Ses01F_script01_1_F034',
#  'Ses01F_script01_1_F038',
#  'Ses01F_script01_1_F042',
#  'Ses01F_script01_1_M000',
#  'Ses01F_script01_1_M001',
#  'Ses01F_script01_1_M002',
#  'Ses01F_script01_1_M003',
#  'Ses01F_script01_1_M004',
#  'Ses01F_script01_1_M007',
#  'Ses01F_script01_1_M010',
#  'Ses01F_script01_1_M012',
#  'Ses01F_script01_1_M014',
#  'Ses01F_script01_1_M015',
#  'Ses01F_script01_1_M016',
#  'Ses01F_script01_1_M017',
#  'Ses01F_script01_1_M023',
#  'Ses01F_script01_1_M024',
#  'Ses01F_script01_1_M025',
#  'Ses01F_script01_1_M034',
#  'Ses01F_script01_1_M039',
#  'Ses01F_script01_1_M040',
#  'Ses01F_script01_2_F003',
#  'Ses01F_script01_2_F004',
#  'Ses01F_script01_2_F005',
#  'Ses01F_script01_2_F006',
#  'Ses01F_script01_2_F007',
#  'Ses01F_script01_2_F008',
#  'Ses01F_script01_2_F009',
#  'Ses01F_script01_2_F010',
#  'Ses01F_script01_2_F011',
#  'Ses01F_script01_2_F012',
#  'Ses01F_script01_2_M001',
#  'Ses01F_script01_2_M004',
#  'Ses01F_script01_2_M008',
#  'Ses01F_script01_2_M017',
#  'Ses01F_script01_3_F000',
#  'Ses01F_script01_3_F001',
#  'Ses01F_script01_3_F002',
#  'Ses01F_script01_3_F003',
#  'Ses01F_script01_3_F004',
#  'Ses01F_script01_3_F005',
#  'Ses01F_script01_3_F006',
#  'Ses01F_script01_3_F007',
#  'Ses01F_script01_3_F008',
#  'Ses01F_script01_3_F009',
#  'Ses01F_script01_3_F010',
#  'Ses01F_script01_3_F011',
#  'Ses01F_script01_3_F012',
#  'Ses01F_script01_3_F013',
#  'Ses01F_script01_3_F014',
#  'Ses01F_script01_3_F015',
#  'Ses01F_script01_3_F016',
#  'Ses01F_script01_3_F017',
#  'Ses01F_script01_3_F018',
#  'Ses01F_script01_3_F019',
#  'Ses01F_script01_3_F020',
#  'Ses01F_script01_3_F021',
#  'Ses01F_script01_3_F022',
#  'Ses01F_script01_3_F028',
#  'Ses01F_script01_3_F029',
#  'Ses01F_script01_3_F030',
#  'Ses01F_script01_3_F031',
#  'Ses01F_script01_3_F035',
#  'Ses01F_script01_3_M000',
#  'Ses01F_script01_3_M001',
#  'Ses01F_script01_3_M003',
#  'Ses01F_script01_3_M004',
#  'Ses01F_script01_3_M005',
#  'Ses01F_script01_3_M008',
#  'Ses01F_script01_3_M009',
#  'Ses01F_script01_3_M010',
#  'Ses01F_script01_3_M015',
#  'Ses01F_script01_3_M016',
#  'Ses01F_script01_3_M017',
#  'Ses01F_script01_3_M018',
#  'Ses01F_script01_3_M019',
#  'Ses01F_script01_3_M020',
#  'Ses01F_script01_3_M021',
#  'Ses01F_script01_3_M022',
#  'Ses01F_script01_3_M023',
#  'Ses01F_script01_3_M024',
#  'Ses01F_script01_3_M026',
#  'Ses01F_script01_3_M027',
#  'Ses01F_script01_3_M028',
#  'Ses01F_script01_3_M029',
#  'Ses01F_script01_3_M030',
#  'Ses01F_script01_3_M032',
#  'Ses01F_script01_3_M033',
#  'Ses01F_script01_3_M036',
#  'Ses01F_script01_3_M037',
#  'Ses01F_script01_3_M038',
#  'Ses01F_script02_1_F000',
#  'Ses01F_script02_1_F004',
#  'Ses01F_script02_1_F006',
#  'Ses01F_script02_1_F007',
#  'Ses01F_script02_1_F008',
#  'Ses01F_script02_1_F009',
#  'Ses01F_script02_1_F010',
#  'Ses01F_script02_1_F015',
#  'Ses01F_script02_1_F024',
#  'Ses01F_script02_1_F025',
#  'Ses01F_script02_1_M000',
#  'Ses01F_script02_1_M001',
#  'Ses01F_script02_1_M002',
#  'Ses01F_script02_1_M004',
#  'Ses01F_script02_1_M007',
#  'Ses01F_script02_1_M008',
#  'Ses01F_script02_1_M009',
#  'Ses01F_script02_1_M010',
#  'Ses01F_script02_1_M011',
#  'Ses01F_script02_1_M013',
#  'Ses01F_script02_1_M014',
#  'Ses01F_script02_1_M015',
#  'Ses01F_script02_1_M016',
#  'Ses01F_script02_1_M020',
#  'Ses01F_script02_1_M021',
#  'Ses01F_script02_1_M023',
#  'Ses01F_script02_1_M024',
#  'Ses01F_script02_1_M025',
#  'Ses01F_script02_1_M026',
#  'Ses01F_script02_1_M028',
#  'Ses01F_script02_1_M029',
#  'Ses01F_script02_1_M031',
#  'Ses01F_script02_1_M032',
#  'Ses01F_script02_1_M033',
#  'Ses01F_script02_1_M034',
#  'Ses01F_script02_1_M035',
#  'Ses01F_script02_1_M036',
#  'Ses01F_script02_1_M037',
#  'Ses01F_script02_1_M038',
#  'Ses01F_script02_1_M039',
#  'Ses01F_script02_1_M040',
#  'Ses01F_script02_1_M041',
#  'Ses01F_script02_1_M042',
#  'Ses01F_script02_1_M043',
#  'Ses01F_script02_1_M044',
#  'Ses01F_script02_2_F000',
#  'Ses01F_script02_2_F001',
#  'Ses01F_script02_2_F006',
#  'Ses01F_script02_2_F008',
#  'Ses01F_script02_2_F009',
#  'Ses01F_script02_2_F010',
#  'Ses01F_script02_2_F015',
#  'Ses01F_script02_2_F016',
#  'Ses01F_script02_2_F017',
#  'Ses01F_script02_2_F019',
#  'Ses01F_script02_2_F022',
#  'Ses01F_script02_2_F023',
#  'Ses01F_script02_2_F026',
#  'Ses01F_script02_2_F034',
#  'Ses01F_script02_2_F035',
#  'Ses01F_script02_2_F036',
#  'Ses01F_script02_2_F040',
#  'Ses01F_script02_2_F041',
#  'Ses01F_script02_2_F043',
#  'Ses01F_script02_2_F044',
#  'Ses01F_script02_2_F045',
#  'Ses01F_script02_2_F046',
#  'Ses01F_script02_2_F047',
#  'Ses01F_script02_2_M000',
#  'Ses01F_script02_2_M001',
#  'Ses01F_script02_2_M002',
#  'Ses01F_script02_2_M006',
#  'Ses01F_script02_2_M016',
#  'Ses01F_script02_2_M017',
#  'Ses01F_script02_2_M019',
#  'Ses01F_script02_2_M021',
#  'Ses01F_script02_2_M022',
#  'Ses01F_script02_2_M023',
#  'Ses01F_script02_2_M024',
#  'Ses01F_script02_2_M026',
#  'Ses01F_script02_2_M033',
#  'Ses01F_script02_2_M037',
#  'Ses01F_script02_2_M038',
#  'Ses01F_script02_2_M040',
#  'Ses01F_script02_2_M042',
#  'Ses01F_script02_2_M043',
#  'Ses01F_script02_2_M044',
#  'Ses01F_script02_2_M046',
#  'Ses01F_script02_2_M047',
#  'Ses01F_script02_2_M048',
#  'Ses01F_script02_2_M049',
#  'Ses01F_script03_1_F003',
#  'Ses01F_script03_1_F004',
#  'Ses01F_script03_1_F005',
#  'Ses01F_script03_1_F006',
#  'Ses01F_script03_1_F007',
#  'Ses01F_script03_1_F008',
#  'Ses01F_script03_1_F009',
#  'Ses01F_script03_1_F010',
#  'Ses01F_script03_1_F011',
#  'Ses01F_script03_1_F012',
#  'Ses01F_script03_1_F013',
#  'Ses01F_script03_1_F014',
#  'Ses01F_script03_1_F015',
#  'Ses01F_script03_1_F019',
#  'Ses01F_script03_1_F020',
#  'Ses01F_script03_1_F021',
#  'Ses01F_script03_1_F022',
#  'Ses01F_script03_1_F023',
#  'Ses01F_script03_1_F024',
#  'Ses01F_script03_1_F025',
#  'Ses01F_script03_1_F026',
#  'Ses01F_script03_1_F027',
#  'Ses01F_script03_1_F028',
#  'Ses01F_script03_1_F029',
#  'Ses01F_script03_1_F030',
#  'Ses01F_script03_1_F031',
#  'Ses01F_script03_1_M005',
#  'Ses01F_script03_1_M007',
#  'Ses01F_script03_1_M008',
#  'Ses01F_script03_1_M009',
#  'Ses01F_script03_1_M010',
#  'Ses01F_script03_1_M011',
#  'Ses01F_script03_1_M013',
#  'Ses01F_script03_1_M014',
#  'Ses01F_script03_1_M015',
#  'Ses01F_script03_1_M016',
#  'Ses01F_script03_1_M017',
#  'Ses01F_script03_1_M018',
#  'Ses01F_script03_1_M019',
#  'Ses01F_script03_1_M020',
#  'Ses01F_script03_1_M021',
#  'Ses01F_script03_1_M022',
#  'Ses01F_script03_1_M023',
#  'Ses01F_script03_1_M024',
#  'Ses01F_script03_1_M025',
#  'Ses01F_script03_1_M026',
#  'Ses01F_script03_1_M027',
#  'Ses01F_script03_1_M028',
#  'Ses01F_script03_1_M029',
#  'Ses01F_script03_1_M031',
#  'Ses01F_script03_1_M032',
#  'Ses01F_script03_1_M033',
#  'Ses01F_script03_1_M034',
#  'Ses01F_script03_1_M036',
#  'Ses01F_script03_1_M037',
#  'Ses01F_script03_2_F000',
#  'Ses01F_script03_2_F001',
#  'Ses01F_script03_2_F002',
#  'Ses01F_script03_2_F003',
#  'Ses01F_script03_2_F004',
#  'Ses01F_script03_2_F005',
#  'Ses01F_script03_2_F013',
#  'Ses01F_script03_2_F014',
#  'Ses01F_script03_2_F015',
#  'Ses01F_script03_2_F016',
#  'Ses01F_script03_2_F017',
#  'Ses01F_script03_2_F018',
#  'Ses01F_script03_2_F021',
#  'Ses01F_script03_2_F022',
#  'Ses01F_script03_2_F023',
#  'Ses01F_script03_2_F024',
#  'Ses01F_script03_2_F025',
#  'Ses01F_script03_2_F026',
#  'Ses01F_script03_2_F027',
#  'Ses01F_script03_2_F028',
#  'Ses01F_script03_2_F029',
#  'Ses01F_script03_2_F030',
#  'Ses01F_script03_2_F031',
#  'Ses01F_script03_2_F032',
#  'Ses01F_script03_2_F034',
#  'Ses01F_script03_2_F035',
#  'Ses01F_script03_2_F036',
#  'Ses01F_script03_2_F037',
#  'Ses01F_script03_2_F038',
#  'Ses01F_script03_2_F039',
#  'Ses01F_script03_2_F040',
#  'Ses01F_script03_2_M001',
#  'Ses01F_script03_2_M002',
#  'Ses01F_script03_2_M004',
#  'Ses01F_script03_2_M007',
#  'Ses01F_script03_2_M010',
#  'Ses01F_script03_2_M011',
#  'Ses01F_script03_2_M014',
#  'Ses01F_script03_2_M016',
#  'Ses01F_script03_2_M018',
#  'Ses01F_script03_2_M019',
#  'Ses01F_script03_2_M021',
#  'Ses01F_script03_2_M022',
#  'Ses01F_script03_2_M023',
#  'Ses01F_script03_2_M024',
#  'Ses01F_script03_2_M025',
#  'Ses01F_script03_2_M026',
#  'Ses01F_script03_2_M029',
#  'Ses01F_script03_2_M030',
#  'Ses01F_script03_2_M031',
#  'Ses01F_script03_2_M032',
#  'Ses01F_script03_2_M033',
#  'Ses01F_script03_2_M034',
#  'Ses01F_script03_2_M035',
#  'Ses01F_script03_2_M036',
#  'Ses01F_script03_2_M037',
#  'Ses01F_script03_2_M038',
#  'Ses01F_script03_2_M039',
#  'Ses01F_script03_2_M040',
#  'Ses01M_impro01_F000',
#  'Ses01M_impro01_F001',
#  'Ses01M_impro01_F007',
#  'Ses01M_impro01_F008',
#  'Ses01M_impro01_F011',
#  'Ses01M_impro01_F012',
#  'Ses01M_impro01_F019',
#  'Ses01M_impro01_F020',
#  'Ses01M_impro01_F021',
#  'Ses01M_impro01_F022',
#  'Ses01M_impro07_M014',
#  'Ses01M_impro07_M015',
#  'Ses01M_impro07_M016',
#  'Ses01M_impro07_M017',
#  'Ses01M_impro07_M018',
#  'Ses01M_impro07_M019',
#  'Ses01M_impro07_M020',
#  'Ses01M_impro07_M024',
#  'Ses01M_impro07_M025',
#  'Ses01M_impro07_M026',
#  'Ses01M_impro07_M027',
#  'Ses01M_impro07_M028',
#  'Ses01M_impro07_M029',
#  'Ses01M_impro07_M030',
#  'Ses01M_impro07_M031',
#  'Ses01M_impro07_M032',
#  'Ses01M_impro07_M033',
#  'Ses01M_script01_1_F004',
#  'Ses01M_script01_1_F005',
#  'Ses01M_script01_1_F006',
#  'Ses01M_script01_1_F008',
#  'Ses01M_script01_1_F011',
#  'Ses01M_script01_1_F014',
#  'Ses01M_script01_1_F016',
#  'Ses01M_script01_1_F017',
#  'Ses01M_script01_1_F020',
#  'Ses01M_script01_1_F023',
#  'Ses01M_script01_1_F024',
#  'Ses01M_script01_1_F025',
#  'Ses01M_script01_1_F026',
#  'Ses01M_script01_1_F029',
#  'Ses01M_script01_1_F030',
#  'Ses01M_script01_1_F031',
#  'Ses01M_script01_1_F032',
#  'Ses01M_script01_1_F035',
#  'Ses01M_script01_1_F036',
#  'Ses01M_script01_1_F037',
#  'Ses01M_script01_1_F039',
#  'Ses01M_script01_1_F040',
#  'Ses01M_script01_1_F041',
#  'Ses01M_script01_1_F042',
#  'Ses01M_script01_1_M000',
#  'Ses01M_script01_1_M002',
#  'Ses01M_script01_1_M003',
#  'Ses01M_script01_1_M004',
#  'Ses01M_script01_1_M005',
#  'Ses01M_script01_1_M006',
#  'Ses01M_script01_1_M007',
#  'Ses01M_script01_1_M017',
#  'Ses01M_script01_1_M020',
#  'Ses01M_script01_1_M021',
#  'Ses01M_script01_1_M023',
#  'Ses01M_script01_1_M024',
#  'Ses01M_script01_1_M034',
#  'Ses01M_script01_1_M035',
#  'Ses01M_script01_1_M037',
#  'Ses01M_script01_1_M038',
#  'Ses01M_script01_1_M040',
#  'Ses01M_script01_1_M041',
#  'Ses01M_script01_1_M042',
#  'Ses01M_script01_2_F000',
#  'Ses01M_script01_2_F001',
#  'Ses01M_script01_2_F004',
#  'Ses01M_script01_2_F005',
#  'Ses01M_script01_2_F009',
#  'Ses01M_script01_2_F011',
#  'Ses01M_script01_2_F012',
#  'Ses01M_script01_2_F013',
#  'Ses01M_script01_2_M000',
#  'Ses01M_script01_2_M001',
#  'Ses01M_script01_2_M007',
#  'Ses01M_script01_2_M015',
#  'Ses01M_script01_2_M017',
#  'Ses01M_script01_3_F000',
#  'Ses01M_script01_3_F001',
#  'Ses01M_script01_3_F003',
#  'Ses01M_script01_3_F004',
#  'Ses01M_script01_3_F005',
#  'Ses01M_script01_3_F006',
#  'Ses01M_script01_3_F008',
#  'Ses01M_script01_3_F009',
#  'Ses01M_script01_3_F010',
#  'Ses01M_script01_3_F011',
#  'Ses01M_script01_3_F012',
#  'Ses01M_script01_3_F013',
#  'Ses01M_script01_3_F014',
#  'Ses01M_script01_3_F015',
#  'Ses01M_script01_3_F016',
#  'Ses01M_script01_3_F017',
#  'Ses01M_script01_3_F018',
#  'Ses01M_script01_3_F019',
#  'Ses01M_script01_3_F021',
#  'Ses01M_script01_3_F022',
#  'Ses01M_script01_3_F023',
#  'Ses01M_script01_3_F024',
#  'Ses01M_script01_3_F025',
#  'Ses01M_script01_3_F026',
#  'Ses01M_script01_3_F030',
#  'Ses01M_script01_3_M000',
#  'Ses01M_script01_3_M001',
#  'Ses01M_script01_3_M002',
#  'Ses01M_script01_3_M004',
#  'Ses01M_script01_3_M006',
#  'Ses01M_script01_3_M007',
#  'Ses01M_script01_3_M009',
#  'Ses01M_script01_3_M010',
#  'Ses01M_script01_3_M012',
#  'Ses01M_script01_3_M014',
#  'Ses01M_script01_3_M015',
#  'Ses01M_script01_3_M016',
#  'Ses01M_script01_3_M017',
#  'Ses01M_script01_3_M018',
#  'Ses01M_script01_3_M019',
#  'Ses01M_script01_3_M020',
#  'Ses01M_script01_3_M021',
#  'Ses01M_script01_3_M022',
#  'Ses01M_script01_3_M023',
#  'Ses01M_script01_3_M024',
#  'Ses01M_script01_3_M025',
#  'Ses01M_script01_3_M026',
#  'Ses01M_script01_3_M027',
#  'Ses01M_script01_3_M028',
#  'Ses01M_script01_3_M029',
#  'Ses01M_script01_3_M030',
#  'Ses01M_script01_3_M031',
#  'Ses01M_script01_3_M032',
#  'Ses01M_script01_3_M033',
#  'Ses01M_script01_3_M034',
#  'Ses01M_script01_3_M035',
#  'Ses01M_script01_3_M036',
#  'Ses01M_script01_3_M037',
#  'Ses01M_script01_3_M038',
#  'Ses01M_script01_3_M039',
#  'Ses01M_script01_3_M040',
#  'Ses01M_script01_3_M041',
#  'Ses01M_script01_3_M043',
#  'Ses01M_script02_1_F007',
#  'Ses01M_script02_1_F008',
#  'Ses01M_script02_1_F009',
#  'Ses01M_script02_1_F014',
#  'Ses01M_script02_1_F017',
#  'Ses01M_script02_1_F021',
#  'Ses01M_script02_1_F023',
#  'Ses01M_script02_1_M000',
#  'Ses01M_script02_1_M001',
#  'Ses01M_script02_1_M002',
#  'Ses01M_script02_1_M004',
#  'Ses01M_script02_1_M005',
#  'Ses01M_script02_1_M007',
#  'Ses01M_script02_1_M009',
#  'Ses01M_script02_1_M010',
#  'Ses01M_script02_1_M011',
#  'Ses01M_script02_1_M012',
#  'Ses01M_script02_1_M014',
#  'Ses01M_script02_1_M016',
#  'Ses01M_script02_1_M017',
#  'Ses01M_script02_1_M018',
#  'Ses01M_script02_1_M019',
#  'Ses01M_script02_1_M022',
#  'Ses01M_script02_1_M023',
#  'Ses01M_script02_1_M028',
#  'Ses01M_script02_1_M030',
#  'Ses01M_script02_1_M031',
#  'Ses01M_script02_1_M032',
#  'Ses01M_script02_1_M037',
#  'Ses01M_script02_1_M039',
#  'Ses01M_script02_1_M040',
#  'Ses01M_script02_1_M041',
#  'Ses01M_script02_1_M042',
#  'Ses01M_script02_1_M043',
#  'Ses01M_script02_1_M044',
#  'Ses01M_script02_1_M045',
#  ...]
