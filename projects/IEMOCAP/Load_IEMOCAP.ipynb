# %% [markdown]
# # IEMOCAPをロードする
#
# - IEMOCAPのロードをするプロジェクト
# - 最終的にライブラリ化する
#
# ※まだ途中

# %% [markdown]
# ## パスの定義

# %%
import os

# %%
wav_dirs = ['../../IEMOCAP_full_release/' + 'Session' + str(i) + '/' + 'sentences/wav/' for i in range(1, 6)] # wavファイルがあるディレクトリ
session_dirs = ['../../IEMOCAP_full_release/' + 'Session' + str(i) + '/dialog/EmoEvaluation/Categorical/' for i in range(1, 6)]

# %%
wav_dirs
# Out:
# ['../../IEMOCAP_full_release/Session1/sentences/wav/',
#  '../../IEMOCAP_full_release/Session2/sentences/wav/',
#  '../../IEMOCAP_full_release/Session3/sentences/wav/',
#  '../../IEMOCAP_full_release/Session4/sentences/wav/',
#  '../../IEMOCAP_full_release/Session5/sentences/wav/']

# %%
session_dirs
# Out:
# ['../../IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Categorical/',
#  '../../IEMOCAP_full_release/Session2/dialog/EmoEvaluation/Categorical/',
#  '../../IEMOCAP_full_release/Session3/dialog/EmoEvaluation/Categorical/',
#  '../../IEMOCAP_full_release/Session4/dialog/EmoEvaluation/Categorical/',
#  '../../IEMOCAP_full_release/Session5/dialog/EmoEvaluation/Categorical/']

# %% [markdown]
# ## 各ファイルにラベルを付与する

# %%
for session_dir in session_dirs:
    label_files_ = sorted(os.listdir(session_dir))
    label_files = []
    for f in label_files_:
        base, ext = os.path.splitext(f)
        if ext == '.txt':
            label_files.append(f)
    
    for f in label_files:
# Out:
# Ses01F_impro01_e2_cat.txt
# Ses01F_impro01_e3_cat.txt
# Ses01F_impro01_e4_cat.txt
# Ses01F_impro02_e1_cat.txt
# Ses01F_impro02_e3_cat.txt
# Ses01F_impro02_e4_cat.txt
# Ses01F_impro03_e1_cat.txt
# Ses01F_impro03_e2_cat.txt
# Ses01F_impro03_e4_cat.txt
# Ses01F_impro04_e1_cat.txt
# Ses01F_impro04_e2_cat.txt
# Ses01F_impro04_e4_cat.txt
# Ses01F_impro05_e1_cat.txt
# Ses01F_impro05_e3_cat.txt
# Ses01F_impro05_e4_cat.txt
# Ses01F_impro06_e1_cat.txt
# Ses01F_impro06_e2_cat.txt
# Ses01F_impro06_e4_cat.txt
# Ses01F_impro07_e1_cat.txt
# Ses01F_impro07_e2_cat.txt
# Ses01F_impro07_e4_cat.txt
# Ses01F_script01_1_e1_cat.txt
# Ses01F_script01_1_e4_cat.txt
# Ses01F_script01_1_e5_cat.txt
# Ses01F_script01_2_e1_cat.txt
# Ses01F_script01_2_e2_cat.txt
# Ses01F_script01_2_e4_cat.txt
# Ses01F_script01_3_e1_cat.txt
# Ses01F_script01_3_e4_cat.txt
# Ses01F_script01_3_e5_cat.txt
# Ses01F_script02_1_e2_cat.txt
# Ses01F_script02_1_e3_cat.txt
# Ses01F_script02_1_e4_cat.txt
# Ses01F_script02_2_e2_cat.txt
# ...

# %%
os.listdir(session_dirs[0])
# Out:
# ['Ses01F_impro04_e4_cat.txt',
#  'Ses01F_script01_2_e1_cat.txt',
#  'Ses01F_impro01_e2_cat.txt',
#  'Ses01F_impro01_e3_cat.txt',
#  'Ses01F_impro06_e2_cat.txt',
#  'Ses01M_script01_2_e1.anvil',
#  'Ses01M_script01_1_e2_cat.txt',
#  'Ses01M_impro07_e1_cat.txt',
#  'Ses01M_impro01_e2.anvil',
#  'Ses01M_impro05_e2.anvil',
#  'Ses01M_impro01_e1_cat.txt',
#  'Ses01M_script01_1_e2.anvil',
#  'Ses01M_impro03_e2.anvil',
#  'Ses01M_impro03_e1.anvil',
#  'Ses01M_impro04_e4_cat.txt',
#  'Ses01M_impro06_e4.anvil',
#  'Ses01F_impro03_e1_cat.txt',
#  'Ses01F_script01_1_e5_cat.txt',
#  'Ses01F_impro05_e1_cat.txt',
#  'Ses01M_impro06_e1.anvil',
#  'Ses01M_impro05_e4.anvil',
#  'Ses01F_script02_1_e2.anvil',
#  'Ses01F_impro01_e2.anvil',
#  'Ses01F_script01_2_e4.anvil',
#  'Ses01F_script01_3_e4_cat.txt',
#  'Ses01M_impro05_e4_cat.txt',
#  'Ses01F_script01_3_e1_cat.txt',
#  'Ses01M_impro07_e2_cat.txt',
#  'Ses01F_impro01_e4.anvil',
#  'Ses01F_script03_1_e2.anvil',
#  'Ses01F_impro04_e2_cat.txt',
# ...

# %%
label_files
# Out:
# ['Ses05F_impro01_e1_cat.txt',
#  'Ses05F_impro01_e2_cat.txt',
#  'Ses05F_impro01_e4_cat.txt',
#  'Ses05F_impro02_e1_cat.txt',
#  'Ses05F_impro02_e2_cat.txt',
#  'Ses05F_impro02_e4_cat.txt',
#  'Ses05F_impro03_e1_cat.txt',
#  'Ses05F_impro03_e2_cat.txt',
#  'Ses05F_impro03_e4_cat.txt',
#  'Ses05F_impro04_e1_cat.txt',
#  'Ses05F_impro04_e2_cat.txt',
#  'Ses05F_impro04_e4_cat.txt',
#  'Ses05F_impro05_e1_cat.txt',
#  'Ses05F_impro05_e2_cat.txt',
#  'Ses05F_impro05_e4_cat.txt',
#  'Ses05F_impro06_e1_cat.txt',
#  'Ses05F_impro06_e2_cat.txt',
#  'Ses05F_impro06_e4_cat.txt',
#  'Ses05F_impro07_e1_cat.txt',
#  'Ses05F_impro07_e2_cat.txt',
#  'Ses05F_impro07_e4_cat.txt',
#  'Ses05F_impro08_e1_cat.txt',
#  'Ses05F_impro08_e2_cat.txt',
#  'Ses05F_impro08_e6_cat.txt',
#  'Ses05F_script01_1_e1_cat.txt',
#  'Ses05F_script01_1_e2_cat.txt',
#  'Ses05F_script01_1_e4_cat.txt',
#  'Ses05F_script01_2_e1_cat.txt',
#  'Ses05F_script01_2_e2_cat.txt',
#  'Ses05F_script01_2_e4_cat.txt',
# ...
